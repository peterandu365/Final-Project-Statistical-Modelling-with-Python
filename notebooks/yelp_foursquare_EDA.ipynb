# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# imports libraries to access foursquare and yelp data
import numpy as np
import pandas as pd
import json
import requests
import sys

# %%
# define the data path:
data_path = '../data/'

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# define the task:

# define a dictionary to store the POIs around each station
# since each POI may have multiple categories from the API, we will use the self-defined category_name as well
# documentation here: https://location.foursquare.com/places/docs/categories

# 'Restaurant': 13065
# 'Bar': 13003
# 'Park': 16032
# 'Transport Hub': 19030
# 'Fuel Station': 19007
# 'EV Charging Station' :19006
# 'Parking': 19020

# Reference:
# dict_POI_yelp = {'Restaurant': 'restaurants, All', 'Bar': 'bars, All', 'Park': 'parks, All', 
#                  'Transport Hub': 'transport, All', 'Fuel Station': 'servicestations, All', 'EV Charging Station': 'evchargingstations, All'}

dict_POI_FS = {'Restaurant': 13065, 'Bar': 13003, 'Park': 16032, 'Transport Hub': 19030, 'Fuel Station': 19007, 'EV Charging Station': 19006, 'Parking': 19020}

# define the radius and number of returns for each query
radius_value = 1000
return_limit = 50

# %%
# declare API keys as global variables, so they can be used in any function, they are not visible in the notebook.
global api_key_FS
# read the api key from the only value in the csv file
api_key_FS = pd.read_csv('~/foursquare api key.csv', header=None).values[0][0]

# %%
# read the target city's stations from the prvious step:
# DF_target_city_stations from the csv file
DF_target_city_stations = pd.read_csv(data_path+'target_city_stations_DF.csv')

# %%
# define the function to get the POIs around each station, by ll and POI category_ID:

def get_venues_ll_category_FS(ll,category_ID = '13003', radius_value=1000,result_FS_limit=50):
    '''
    This function gets the venues around a given location, by ll and category_ID.
    
    Parameters:
    ll: the location of the station, in the format of 'lat,lng'
    category_ID: the category_ID of the POI, default is '13003' for bars
    radius_value: the radius around the station to search for POIs, default is 1000m
    result_FS_limit: the maximum number of POIs to return, default is 50, which is also the maximum value allowed by the API free version.
    
    Reference: 
    https://developer.foursquare.com/docs/api-reference/venues/search/
    https://location.foursquare.com/places/docs/categories

    13065	Dining and Drinking > Restaurant
    13003	Dining and Drinking > Bar
    16032	Landmarks and Outdoors > Park
    19030	Travel and Transportation > Transport Hub
    19007	Travel and Transportation > Fuel Station
    19006	Travel and Transportation > Electric Vehicle Charging Station
    19020	Travel and Transportation > Parking

    Example:
    get_venues_ll_category_FS('43.6532,-79.3832','13003',1000,50)
    '''
    
    # requests URL:
    URL = 'https://api.foursquare.com/v3/places/search?'
    
    # course example:
    # https://data.compass.lighthouselabs.ca/days/w02d4/activities/160

    # define the headers and parameters:
    headers = {
        "accept": "application/json",
        "Authorization": api_key_FS
    }
    params = {}
    params['ll'] = ll
    params['radius'] = radius_value
    params['categories'] = category_ID
    params['limit'] = result_FS_limit
   
    response = requests.get(URL, headers=headers, params=params)
    data = response.json()
    return data

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# before the looping, delete any existing csv file with the name like:
for POI_name, POI_ID in dict_POI_FS.items():
    # delete the existing csv file
    # replace the space in the POI_name with '_', so the file name is valid
    d = data_path+'POI_FS_'+POI_name.replace(' ', '_')+'_'+str(POI_ID)+'.csv'
    # !rm $d

# call the function to get the POIs around each station, for each stations, for each POI category:

# for each POI category, save the result into a csv file, named as POI_FS_{category_ID}_{category_Name}.csv

# for loop for dict_POI_FS, key and value:
for POI_name, POI_ID in dict_POI_FS.items():
    # print to separate the output of each POI category, in yellow color:
    print('\033[93m' + '\n===============================' + '\033[0m')
    print("name: ", POI_name, "id: ", POI_ID)


    df_FS_POIs_around_stations = pd.DataFrame()

    for i in range(len(DF_target_city_stations)): # debug # range(10): #
        
        print('\n===============================')      
        print('station: ', DF_target_city_stations['station_name'][i]) 
        print("name: ", POI_name, "id: ", POI_ID)# debug
        
        # One option to tranfer the ll as an augument to the function:
        # cat the longitude and latitude of the station into a string, in the format of 'lat,lng' from the DF_target_city_stations
        # cat_string = str(DF_target_city_stations['latitude'][i])+','+str(DF_target_city_stations['longitude'][i])
        # call the function to get the POIs around each station, by ll and POI category_ID:
        # try: 
        result_FS = get_venues_ll_category_FS(str(DF_target_city_stations['latitude'][i])+','+str(DF_target_city_stations['longitude'][i]), str(POI_ID), radius_value, return_limit)

        # However, it requires more calculation, and the function can be more general, so another option is to pass the ll as a string.
        
        df_FS_normalize_1run_method = pd.json_normalize(result_FS['results'], record_path=['categories'], meta=['fsq_id',  'distance', 'link', 'name',
        'timezone'], record_prefix='categories_', errors='ignore') # 'chains', column is not always returned, so ignore it.

        # add the station_ID to  df_FS_normalize_1run_method, and fill it with the station ID from DF_target_city_stations['station_id'][i]
        df_FS_normalize_1run_method['station_id'] = DF_target_city_stations['station_id'][i]

        # add a station_name collumn to  df_FS_normalize_1run_method, and fill it with the station name from DF_target_city_stations['station_name'][i]
        df_FS_normalize_1run_method['station_name'] = DF_target_city_stations['station_name'][i]
        
        # add a POI_ID collumn to  df_FS_normalize_1run_method, and fill it with the POI_ID from dict_POI_FS[POI_ID]
        df_FS_normalize_1run_method['POI_category_ID'] = dict_POI_FS[POI_name]
        
        # add a POI_name collumn to  df_FS_normalize_1run_method, and fill it with the POI_name from dict_POI_FS[POI_ID]
        df_FS_normalize_1run_method['POI_category_name'] = POI_name
        
        # concat the  df_FS_normalize_1run_method to df_FS_POIs_around_stations
        df_FS_POIs_around_stations = pd.concat([df_FS_POIs_around_stations, df_FS_normalize_1run_method], axis=0)
        print(df_FS_POIs_around_stations.shape)
            
        # except:
            # print the error type:
            # print('Error code: ', sys.exc_info()[0])
        


    # re-order the columns in df_FS_POIs_around_stations, make it permanent. inplace=True
    # if df_FS_POIs_around_stations is empty, then skip this step
    # try except: if exception, show the error message, but continue the loop
    try:
        df_FS_POIs_around_stations = df_FS_POIs_around_stations[['POI_category_name', 'POI_category_ID', 'station_id', 'station_name', 'fsq_id', 'name', 'distance', 'timezone', 'link', 'categories_id', 'categories_name', 'categories_icon.prefix', 'categories_icon.suffix']]    
    except:
        print('Error code: ', sys.exc_info()[0])
    # rename the "name" column to "POI_name"
    df_FS_POIs_around_stations.rename(columns={'name': 'POI_name'}, inplace=True)
        
    # save the df_FS_POIs_around_stations to a csv file with file name surfix as POI_FS_{category_ID}_{category_Name}.csv
    # if exists, overwrite it.
    df_FS_POIs_around_stations.to_csv(data_path+'POI_FS_'+POI_name.replace(' ', '_')+'_'+str(POI_ID)+'.csv', index=False)

print('\nFS loop Done!')
# Out:
# rm: ../data/POI_FS_Restaurant_13065.csv: No such file or directory
# rm: ../data/POI_FS_Bar_13003.csv: No such file or directory
# rm: ../data/POI_FS_Park_16032.csv: No such file or directory
# rm: ../data/POI_FS_Transport_Hub_19030.csv: No such file or directory
# rm: ../data/POI_FS_Fuel_Station_19007.csv: No such file or directory
# rm: ../data/POI_FS_EV_Charging_Station_19006.csv: No such file or directory
# rm: ../data/POI_FS_Parking_19020.csv: No such file or directory
#
# ===============================
# name:  Restaurant id:  13065
#
# ===============================
# station:  10th & Cambie
# name:  Restaurant id:  13065
# (89, 13)
#
# ===============================
# station:  Yaletown-Roundhouse Station
# name:  Restaurant id:  13065
# (170, 13)
#
# ===============================
# station:  Dunsmuir & Beatty
# name:  Restaurant id:  13065
# (264, 13)
#
# ===============================
# station:  12th & Yukon (City Hall)
# name:  Restaurant id:  13065
# (351, 13)
#
# ===============================
# station:  8th & Ash
# name:  Restaurant id:  13065
# (429, 13)
#
# ===============================
# station:  Spyglass & Seawall
# name:  Restaurant id:  13065
# (517, 13)
#
# ===============================
# station:  Stamps Landing
# name:  Restaurant id:  13065
# (598, 13)
#
# ===============================
# station:  Ontario & Seawall
# name:  Restaurant id:  13065
# (707, 13)
#
# ===============================
# station:  Canada Place
# name:  Restaurant id:  13065
# (806, 13)
#
# ===============================
# station:  Granville & Georgia
# name:  Restaurant id:  13065
# (898, 13)
#
# ===============================
# station:  Pender & Burrard
# name:  Restaurant id:  13065
# (998, 13)
#
# ===============================
# station:  Marinaside & Davie
# name:  Restaurant id:  13065
# (1082, 13)
#
# ===============================
# station:  Robson & Hornby
# name:  Restaurant id:  13065
# (1174, 13)
#
# ===============================
# station:  Cordova & Granville
# name:  Restaurant id:  13065
# (1274, 13)
#
# ===============================
# station:  Hornby & Pender
# name:  Restaurant id:  13065
# (1368, 13)
#
# ===============================
# station:  Homer & Robson (Vancouver Public Library)
# name:  Restaurant id:  13065
# (1460, 13)
#
# ===============================
# station:  Beatty & Robson
# name:  Restaurant id:  13065
# (1553, 13)
#
# ===============================
# station:  Beatty & Nelson
# name:  Restaurant id:  13065
# (1643, 13)
#
# ===============================
# station:  Abbott & Cordova
# name:  Restaurant id:  13065
# (1739, 13)
#
# ===============================
# station:  Comox & Denman
# name:  Restaurant id:  13065
# (1841, 13)
#
# ===============================
# station:  Cordova & Bute
# name:  Restaurant id:  13065
# (1940, 13)
#
# ===============================
# station:  Hornby & Nelson
# name:  Restaurant id:  13065
# (2029, 13)
#
# ===============================
# station:  Helmcken & Burrard
# name:  Restaurant id:  13065
# (2114, 13)
#
# ===============================
# station:  Pacific & Richards
# name:  Restaurant id:  13065
# (2195, 13)
#
# ===============================
# station:  Chilco & Beach
# name:  Restaurant id:  13065
# (2283, 13)
#
# ===============================
# station:  Comox & Broughton
# name:  Restaurant id:  13065
# (2379, 13)
#
# ===============================
# station:  Bute & Comox
# name:  Restaurant id:  13065
# (2475, 13)
#
# ===============================
# station:  Cambie & Water
# name:  Restaurant id:  13065
# (2573, 13)
#
# ===============================
# station:  Keefer & Abbott
# name:  Restaurant id:  13065
# (2673, 13)
#
# ===============================
# station:  Expo & Carrall
# name:  Restaurant id:  13065
# (2777, 13)
#
# ===============================
# station:  Keefer & Columbia
# name:  Restaurant id:  13065
# (2888, 13)
#
# ===============================
# station:  Marinaside & Cooperage
# name:  Restaurant id:  13065
# (2976, 13)
#
# ===============================
# station:  Bidwell & Burnaby
# name:  Restaurant id:  13065
# (3066, 13)
#
# ===============================
# station:  Robson & Granville
# name:  Restaurant id:  13065
# (3159, 13)
#
# ===============================
# station:  Expo & Smithe
# name:  Restaurant id:  13065
# (3253, 13)
#
# ===============================
# station:  Cypress & Cornwall
# name:  Restaurant id:  13065
# (3345, 13)
#
# ===============================
# station:  Anderson & 2nd
# name:  Restaurant id:  13065
# (3440, 13)
#
# ===============================
# station:  7th & Granville
# name:  Restaurant id:  13065
# (3536, 13)
#
# ===============================
# station:  10th & Granville
# name:  Restaurant id:  13065
# (3628, 13)
#
# ===============================
# station:  14th & Granville
# name:  Restaurant id:  13065
# (3706, 13)
#
# ===============================
# station:  14th & Cambie
# name:  Restaurant id:  13065
# (3778, 13)
#
# ===============================
# station:  Ontario & 5th
# name:  Restaurant id:  13065
# (3880, 13)
#
# ===============================
# station:  10th & Main
# name:  Restaurant id:  13065
# (3983, 13)
#
# ===============================
# station:  Cypress & 4th
# name:  Restaurant id:  13065
# (4080, 13)
#
# ===============================
# station:  Vanier Park
# name:  Restaurant id:  13065
# (4167, 13)
#
# ===============================
# station:  Nelson & Mainland
# name:  Restaurant id:  13065
# (4258, 13)
#
# ===============================
# station:  Nelson & Richards
# name:  Restaurant id:  13065
# (4345, 13)
#
# ===============================
# station:  7th & Heather
# name:  Restaurant id:  13065
# (4424, 13)
#
# ===============================
# station:  Harwood & Bute
# name:  Restaurant id:  13065
# (4520, 13)
#
# ===============================
# station:  Chilco & Barclay
# name:  Restaurant id:  13065
# (4614, 13)
#
# ===============================
# station:  Chilco & Robson
# name:  Restaurant id:  13065
# (4710, 13)
#
# ===============================
# station:  Nicola & Robson
# name:  Restaurant id:  13065
# (4809, 13)
#
# ===============================
# station:  Carrall & Hastings
# name:  Restaurant id:  13065
# (4917, 13)
#
# ===============================
# station:  šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery
# name:  Restaurant id:  13065
# (5014, 13)
#
# ===============================
# station:  Stanley Park - Vancouver Aquarium
# name:  Restaurant id:  13065
# (5061, 13)
#
# ===============================
# station:  Stanley Park - Second Beach North
# name:  Restaurant id:  13065
# (5070, 13)
#
# ===============================
# station:  Stanley Park - Second Beach South
# name:  Restaurant id:  13065
# (5124, 13)
#
# ===============================
# station:  Stanley Park - Totem Poles
# name:  Restaurant id:  13065
# (5140, 13)
#
# ===============================
# station:  Heather & 14th
# name:  Restaurant id:  13065
# (5216, 13)
#
# ===============================
# station:  8th & Ontario
# name:  Restaurant id:  13065
# (5322, 13)
#
# ===============================
# station:  1st & Chestnut
# name:  Restaurant id:  13065
# (5419, 13)
#
# ===============================
# station:  7th & Arbutus
# name:  Restaurant id:  13065
# (5512, 13)
#
# ===============================
# station:  5th & Arbutus
# name:  Restaurant id:  13065
# (5607, 13)
#
# ===============================
# station:  10th & Oak
# name:  Restaurant id:  13065
# (5693, 13)
#
# ===============================
# station:  Arbutus & 16th
# name:  Restaurant id:  13065
# (5735, 13)
#
# ===============================
# station:  Cypress & 14th
# name:  Restaurant id:  13065
# (5818, 13)
#
# ===============================
# station:  Cypress & 16th
# name:  Restaurant id:  13065
# (5899, 13)
#
# ===============================
# station:  Georgia & Thurlow
# name:  Restaurant id:  13065
# (5996, 13)
#
# ===============================
# station:  Thurlow & Pendrell
# name:  Restaurant id:  13065
# (6086, 13)
#
# ===============================
# station:  Heather & 16th
# name:  Restaurant id:  13065
# (6168, 13)
#
# ===============================
# station:  14th & Ontario
# name:  Restaurant id:  13065
# (6264, 13)
#
# ===============================
# station:  14th & Main
# name:  Restaurant id:  13065
# (6364, 13)
#
# ===============================
# station:  David Lam Park - West
# name:  Restaurant id:  13065
# (6448, 13)
#
# ===============================
# station:  Beach & Seymour
# name:  Restaurant id:  13065
# (6530, 13)
#
# ===============================
# station:  Richards & Helmcken
# name:  Restaurant id:  13065
# (6615, 13)
#
# ===============================
# station:  Burrard & 4th
# name:  Restaurant id:  13065
# (6713, 13)
#
# ===============================
# station:  Burrard & 7th
# name:  Restaurant id:  13065
# (6814, 13)
#
# ===============================
# station:  South False Creek Seawall
# name:  Restaurant id:  13065
# (6902, 13)
#
# ===============================
# station:  Chestnut & McNicoll
# name:  Restaurant id:  13065
# (6994, 13)
#
# ===============================
# station:  Creekside Park North
# name:  Restaurant id:  13065
# (7100, 13)
#
# ===============================
# station:  Alexander & Main
# name:  Restaurant id:  13065
# (7211, 13)
#
# ===============================
# station:  Arbutus Greenway & 14th
# name:  Restaurant id:  13065
# (7269, 13)
#
# ===============================
# station:  Arbutus Greenway & Fir
# name:  Restaurant id:  13065
# (7368, 13)
#
# ===============================
# station:  Kitsilano Beach Park
# name:  Restaurant id:  13065
# (7458, 13)
#
# ===============================
# station:  Arbutus & McNicoll
# name:  Restaurant id:  13065
# (7531, 13)
#
# ===============================
# station:  Vine & 4th
# name:  Restaurant id:  13065
# (7625, 13)
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Restaurant id:  13065
# (7734, 13)
#
# ===============================
# station:  Alder & 11th
# name:  Restaurant id:  13065
# (7819, 13)
#
# ===============================
# station:  10th & Columbia
# name:  Restaurant id:  13065
# (7924, 13)
#
# ===============================
# station:  1st & Manitoba
# name:  Restaurant id:  13065
# (8026, 13)
#
# ===============================
# station:  10th & Ontario
# name:  Restaurant id:  13065
# (8131, 13)
#
# ===============================
# station:  Quebec & 1st
# name:  Restaurant id:  13065
# (8243, 13)
#
# ===============================
# station:  Columbia & 14th
# name:  Restaurant id:  13065
# (8335, 13)
#
# ===============================
# station:  Bute & Davie
# name:  Restaurant id:  13065
# (8430, 13)
#
# ===============================
# station:  7th & Laurel
# name:  Restaurant id:  13065
# (8514, 13)
#
# ===============================
# station:  7th &  Alder
# name:  Restaurant id:  13065
# (8609, 13)
#
# ===============================
# station:  Science World
# name:  Restaurant id:  13065
# (8715, 13)
#
# ===============================
# station:  1st & Scotia
# name:  Restaurant id:  13065
# (8816, 13)
#
# ===============================
# station:  Georgia & Main
# name:  Restaurant id:  13065
# (8928, 13)
#
# ===============================
# station:  Shaw Tower
# name:  Restaurant id:  13065
# (9026, 13)
#
# ===============================
# station:  Pine & 14th
# name:  Restaurant id:  13065
# (9110, 13)
#
# ===============================
# station:  York & Yew
# name:  Restaurant id:  13065
# (9197, 13)
#
# ===============================
# station:  Pine & 10th
# name:  Restaurant id:  13065
# (9292, 13)
#
# ===============================
# station:  8th & Scotia
# name:  Restaurant id:  13065
# (9396, 13)
#
# ===============================
# station:  Alberni & Jervis
# name:  Restaurant id:  13065
# (9493, 13)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Restaurant id:  13065
# (9562, 13)
#
# ===============================
# station:  14th & Alder
# name:  Restaurant id:  13065
# (9645, 13)
#
# ===============================
# station:  Pender & Gore
# name:  Restaurant id:  13065
# (9753, 13)
#
# ===============================
# station:  Carrall & Seawall
# name:  Restaurant id:  13065
# (9854, 13)
#
# ===============================
# station:  Glen & Union
# name:  Restaurant id:  13065
# (9932, 13)
#
# ===============================
# station:  Adanac & McLean
# name:  Restaurant id:  13065
# (10022, 13)
#
# ===============================
# station:  Commercial & Adanac
# name:  Restaurant id:  13065
# (10117, 13)
#
# ===============================
# station:  Pender & Commercial
# name:  Restaurant id:  13065
# (10205, 13)
#
# ===============================
# station:  Keefer & Princess
# name:  Restaurant id:  13065
# (10303, 13)
#
# ===============================
# station:  Alexander & Railway
# name:  Restaurant id:  13065
# (10400, 13)
#
# ===============================
# station:  Napier & Commercial
# name:  Restaurant id:  13065
# (10494, 13)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Restaurant id:  13065
# (10588, 13)
#
# ===============================
# station:  Thornton & National
# name:  Restaurant id:  13065
# (10691, 13)
#
# ===============================
# station:  Keith & 6th
# name:  Restaurant id:  13065
# (10769, 13)
#
# ===============================
# station:  Glen & 6th
# name:  Restaurant id:  13065
# (10847, 13)
#
# ===============================
# station:  Grant & Commercial
# name:  Restaurant id:  13065
# (10939, 13)
#
# ===============================
# station:  2nd & Commercial
# name:  Restaurant id:  13065
# (11033, 13)
#
# ===============================
# station:  4th & Commercial
# name:  Restaurant id:  13065
# (11124, 13)
#
# ===============================
# station:  8th & Commercial
# name:  Restaurant id:  13065
# (11211, 13)
#
# ===============================
# station:  10th & Commercial
# name:  Restaurant id:  13065
# (11290, 13)
#
# ===============================
# station:  Woodland & 10th
# name:  Restaurant id:  13065
# (11367, 13)
#
# ===============================
# station:  Glen & Broadway
# name:  Restaurant id:  13065
# (11437, 13)
#
# ===============================
# station:  St George & Broadway
# name:  Restaurant id:  13065
# (11540, 13)
#
# ===============================
# station:  7th & Woodland
# name:  Restaurant id:  13065
# (11631, 13)
#
# ===============================
# station:  Woodland & 4th
# name:  Restaurant id:  13065
# (11724, 13)
#
# ===============================
# station:  Woodland & Graveley
# name:  Restaurant id:  13065
# (11818, 13)
#
# ===============================
# station:  Charles & Woodland
# name:  Restaurant id:  13065
# (11913, 13)
#
# ===============================
# station:  18th & Main
# name:  Restaurant id:  13065
# (12003, 13)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Restaurant id:  13065
# (12099, 13)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Restaurant id:  13065
# (12197, 13)
#
# ===============================
# station:  13th & St George
# name:  Restaurant id:  13065
# (12290, 13)
#
# ===============================
# station:  10th & Fraser
# name:  Restaurant id:  13065
# (12382, 13)
#
# ===============================
# station:  8th & Fraser
# name:  Restaurant id:  13065
# (12460, 13)
#
# ===============================
# station:  St Catherines & 10th
# name:  Restaurant id:  13065
# (12508, 13)
#
# ===============================
# station:  St Catherines & 7th
# name:  Restaurant id:  13065
# (12552, 13)
#
# ===============================
# station:  Pender & Victoria
# name:  Restaurant id:  13065
# (12637, 13)
#
# ===============================
# station:  Victoria & 4th
# name:  Restaurant id:  13065
# (12729, 13)
#
# ===============================
# station:  Victoria & 10th
# name:  Restaurant id:  13065
# (12816, 13)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Restaurant id:  13065
# (12882, 13)
#
# ===============================
# station:  Triumph & Victoria
# name:  Restaurant id:  13065
# (12966, 13)
#
# ===============================
# station:  Windsor & 14th
# name:  Restaurant id:  13065
# (13023, 13)
#
# ===============================
# station:  14th & Fraser
# name:  Restaurant id:  13065
# (13118, 13)
#
# ===============================
# station:  15th & Knight
# name:  Restaurant id:  13065
# (13179, 13)
#
# ===============================
# station:  Commercial & Pandora
# name:  Restaurant id:  13065
# (13263, 13)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Restaurant id:  13065
# (13346, 13)
#
# ===============================
# station:  6th & Prince Edward
# name:  Restaurant id:  13065
# (13449, 13)
#
# ===============================
# station:  6th & Carolina
# name:  Restaurant id:  13065
# (13543, 13)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Restaurant id:  13065
# (13546, 13)
#
# ===============================
# station:  Union & Dunlevy
# name:  Restaurant id:  13065
# (13645, 13)
#
# ===============================
# station:  Keefer & Hawks
# name:  Restaurant id:  13065
# (13746, 13)
#
# ===============================
# station:  Hawks & Union
# name:  Restaurant id:  13065
# (13847, 13)
#
# ===============================
# station:  Charles & Commercial
# name:  Restaurant id:  13065
# (13940, 13)
#
# ===============================
# station:  10th & Kingsway
# name:  Restaurant id:  13065
# (14046, 13)
#
# ===============================
# station:  Beach & Hornby
# name:  Restaurant id:  13065
# (14133, 13)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Restaurant id:  13065
# (14233, 13)
#
# ===============================
# station:  Bute & Barclay
# name:  Restaurant id:  13065
# (14324, 13)
#
# ===============================
# station:  8th & Yukon
# name:  Restaurant id:  13065
# (14423, 13)
#
# ===============================
# station:  Princess & Union
# name:  Restaurant id:  13065
# (14527, 13)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Restaurant id:  13065
# (14620, 13)
#
# ===============================
# station:  5th & Main
# name:  Restaurant id:  13065
# (14723, 13)
#
# ===============================
# station:  3rd & Quebec
# name:  Restaurant id:  13065
# (14825, 13)
#
# ===============================
# station:  Richards & Cordova
# name:  Restaurant id:  13065
# (14922, 13)
#
# ===============================
# station:  Richards & Robson
# name:  Restaurant id:  13065
# (15012, 13)
#
# ===============================
# station:  Olympic Village Station
# name:  Restaurant id:  13065
# (15094, 13)
#
# ===============================
# station:  Campbell & Hastings
# name:  Restaurant id:  13065
# (15153, 13)
#
# ===============================
# station:  Cardero & Davie
# name:  Restaurant id:  13065
# (15248, 13)
#
# ===============================
# station:  Aquatic Centre
# name:  Restaurant id:  13065
# (15340, 13)
#
# ===============================
# station:  Beach & Broughton
# name:  Restaurant id:  13065
# (15430, 13)
#
# ===============================
# station:  Beach & Cardero
# name:  Restaurant id:  13065
# (15519, 13)
#
# ===============================
# station:  Georgia & Homer
# name:  Restaurant id:  13065
# (15609, 13)
#
# ===============================
# station:  Columbia & 5th
# name:  Restaurant id:  13065
# (15708, 13)
#
# ===============================
# station:  Haro & Denman
# name:  Restaurant id:  13065
# (15811, 13)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Restaurant id:  13065
# (15817, 13)
#
# ===============================
# station:  Arbutus & 10th
# name:  Restaurant id:  13065
# (15910, 13)
#
# ===============================
# station:  Ontario & 16th
# name:  Restaurant id:  13065
# (16003, 13)
#
# ===============================
# station:  Richards & Davie
# name:  Restaurant id:  13065
# (16083, 13)
#
# ===============================
# station:  8th & Prince Edward
# name:  Restaurant id:  13065
# (16187, 13)
#
# ===============================
# station:  Jervis & Robson
# name:  Restaurant id:  13065
# (16283, 13)
#
# ===============================
# station:  Smithe & Burrard
# name:  Restaurant id:  13065
# (16376, 13)
#
# ===============================
# station:  Broughton & Davie
# name:  Restaurant id:  13065
# (16471, 13)
#
# ===============================
# station:  Cypress & 10th
# name:  Restaurant id:  13065
# (16570, 13)
#
# ===============================
# station:  Granville Island
# name:  Restaurant id:  13065
# (16662, 13)
#
# ===============================
# station:  McLean & Pender
# name:  Restaurant id:  13065
# (16752, 13)
#
# ===============================
# station:  Richards & Smithe
# name:  Restaurant id:  13065
# (16841, 13)
#
# ===============================
# station:  Bute & Robson
# name:  Restaurant id:  13065
# (16931, 13)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Restaurant id:  13065
# (16998, 13)
#
# ===============================
# station:  Alma & Point Grey
# name:  Restaurant id:  13065
# (17061, 13)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Restaurant id:  13065
# (17142, 13)
#
# ===============================
# station:  Hastings & Broughton
# name:  Restaurant id:  13065
# (17237, 13)
#
# ===============================
# station:  Yew & Broadway
# name:  Restaurant id:  13065
# (17325, 13)
#
# ===============================
# station:  8th & Macdonald
# name:  Restaurant id:  13065
# (17402, 13)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Restaurant id:  13065
# (17490, 13)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Restaurant id:  13065
# (17585, 13)
#
# ===============================
# station:  Grandview & Commercial
# name:  Restaurant id:  13065
# (17678, 13)
#
# ===============================
# station:  14th & Oak
# name:  Restaurant id:  13065
# (17760, 13)
#
# ===============================
# station:  Wallace & 4th
# name:  Restaurant id:  13065
# (17830, 13)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Restaurant id:  13065
# (17919, 13)
#
# ===============================
# station:  Balaclava & 6th
# name:  Restaurant id:  13065
# (18007, 13)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Restaurant id:  13065
# (18097, 13)
#
# ===============================
# station:  Dunbar & 6th
# name:  Restaurant id:  13065
# (18193, 13)
#
# ===============================
# station:  18th & Cambie
# name:  Restaurant id:  13065
# (18254, 13)
#
# ===============================
# station:  Blenheim & 4th
# name:  Restaurant id:  13065
# (18353, 13)
#
# ===============================
# station:  18th & Heather
# name:  Restaurant id:  13065
# (18428, 13)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Restaurant id:  13065
# (18501, 13)
#
# ===============================
# station:  20th & Main
# name:  Restaurant id:  13065
# (18596, 13)
#
# ===============================
# station:  Station & Terminal
# name:  Restaurant id:  13065
# (18707, 13)
#
# ===============================
# station:  Jericho Beach
# name:  Restaurant id:  13065
# (18770, 13)
#
# ===============================
# station:  Burrard & Drake
# name:  Restaurant id:  13065
# (18860, 13)
#
# ===============================
# station:  Columbia & 1st
# name:  Restaurant id:  13065
# (18955, 13)
#
# ===============================
# station:  Davie & Beach
# name:  Restaurant id:  13065
# (19046, 13)
#
# ===============================
# station:  Morton & Denman
# name:  Restaurant id:  13065
# (19137, 13)
#
# ===============================
# station:  13th & Cambie
# name:  Restaurant id:  13065
# (19211, 13)
#
# ===============================
# station:  Nelson & Denman
# name:  Restaurant id:  13065
# (19311, 13)
#
# ===============================
# station:  Melville & Bute
# name:  Restaurant id:  13065
# (19408, 13)
#
# ===============================
# station:  Seymour & Cordova
# name:  Restaurant id:  13065
# (19504, 13)
#
# ===============================
# station:  Arbutus & Nanton
# name:  Restaurant id:  13065
# (19509, 13)
#
# ===============================
# station:  Yukon & 6th
# name:  Restaurant id:  13065
# (19607, 13)
#
# ===============================
# station:  11th & Kingsway
# name:  Restaurant id:  13065
# (19714, 13)
#
# ===============================
# station:  Wylie & 2nd
# name:  Restaurant id:  13065
# (19805, 13)
#
# ===============================
# station:  29th & Cambie
# name:  Restaurant id:  13065
# (19834, 13)
#
# ===============================
# station:  Rolston & Granville
# name:  Restaurant id:  13065
# (19919, 13)
#
# ===============================
# station:  East Blvd & 37th
# name:  Restaurant id:  13065
# (20012, 13)
#
# ===============================
# station:  28th & Willow
# name:  Restaurant id:  13065
# (20049, 13)
#
# ===============================
# station:  Ontario & 23rd
# name:  Restaurant id:  13065
# (20138, 13)
#
# ===============================
# station:  30th & Ontario
# name:  Restaurant id:  13065
# (20218, 13)
#
# ===============================
# station:  Franklin & Nanaimo
# name:  Restaurant id:  13065
# (20292, 13)
#
# ===============================
# station:  Lakewood & Triumph
# name:  Restaurant id:  13065
# (20360, 13)
#
# ===============================
# station:  Wall & Eton
# name:  Restaurant id:  13065
# (20436, 13)
#
# ===============================
# station:  Lakewood & Oxford
# name:  Restaurant id:  13065
# (20515, 13)
#
# ===============================
# station:  22nd & Cambie
# name:  Restaurant id:  13065
# (20573, 13)
#
# ===============================
# station:  King Edward & Cambie
# name:  Restaurant id:  13065
# (20628, 13)
#
# ===============================
# station:  Heather & 29th
# name:  Restaurant id:  13065
# (20667, 13)
#
# ===============================
# station:  Cardero & Robson
# name:  Restaurant id:  13065
# (20767, 13)
#
# ===============================
# station:  Commercial & 20th
# name:  Restaurant id:  13065
# (20829, 13)
#
# ===============================
# station:  Hornby & Drake
# name:  Restaurant id:  13065
# (20918, 13)
#
# ===============================
# station:  Burrard & 14th
# name:  Restaurant id:  13065
# (21012, 13)
#
# ===============================
# name:  Bar id:  13003
#
# ===============================
# station:  10th & Cambie
# name:  Bar id:  13003
# (54, 13)
#
# ===============================
# station:  Yaletown-Roundhouse Station
# name:  Bar id:  13003
# (158, 13)
#
# ===============================
# station:  Dunsmuir & Beatty
# name:  Bar id:  13003
# (277, 13)
#
# ===============================
# station:  12th & Yukon (City Hall)
# name:  Bar id:  13003
# (335, 13)
#
# ===============================
# station:  8th & Ash
# name:  Bar id:  13003
# (374, 13)
#
# ===============================
# station:  Spyglass & Seawall
# name:  Bar id:  13003
# (457, 13)
#
# ===============================
# station:  Stamps Landing
# name:  Bar id:  13003
# (547, 13)
#
# ===============================
# station:  Ontario & Seawall
# name:  Bar id:  13003
# (639, 13)
#
# ===============================
# station:  Canada Place
# name:  Bar id:  13003
# (746, 13)
#
# ===============================
# station:  Granville & Georgia
# name:  Bar id:  13003
# (864, 13)
#
# ===============================
# station:  Pender & Burrard
# name:  Bar id:  13003
# (976, 13)
#
# ===============================
# station:  Marinaside & Davie
# name:  Bar id:  13003
# (1082, 13)
#
# ===============================
# station:  Robson & Hornby
# name:  Bar id:  13003
# (1198, 13)
#
# ===============================
# station:  Cordova & Granville
# name:  Bar id:  13003
# (1311, 13)
#
# ===============================
# station:  Hornby & Pender
# name:  Bar id:  13003
# (1425, 13)
#
# ===============================
# station:  Homer & Robson (Vancouver Public Library)
# name:  Bar id:  13003
# (1544, 13)
#
# ===============================
# station:  Beatty & Robson
# name:  Bar id:  13003
# (1665, 13)
#
# ===============================
# station:  Beatty & Nelson
# name:  Bar id:  13003
# (1775, 13)
#
# ===============================
# station:  Abbott & Cordova
# name:  Bar id:  13003
# (1889, 13)
#
# ===============================
# station:  Comox & Denman
# name:  Bar id:  13003
# (1947, 13)
#
# ===============================
# station:  Cordova & Bute
# name:  Bar id:  13003
# (2052, 13)
#
# ===============================
# station:  Hornby & Nelson
# name:  Bar id:  13003
# (2158, 13)
#
# ===============================
# station:  Helmcken & Burrard
# name:  Bar id:  13003
# (2261, 13)
#
# ===============================
# station:  Pacific & Richards
# name:  Bar id:  13003
# (2364, 13)
#
# ===============================
# station:  Chilco & Beach
# name:  Bar id:  13003
# (2388, 13)
#
# ===============================
# station:  Comox & Broughton
# name:  Bar id:  13003
# (2466, 13)
#
# ===============================
# station:  Bute & Comox
# name:  Bar id:  13003
# (2568, 13)
#
# ===============================
# station:  Cambie & Water
# name:  Bar id:  13003
# (2679, 13)
#
# ===============================
# station:  Keefer & Abbott
# name:  Bar id:  13003
# (2794, 13)
#
# ===============================
# station:  Expo & Carrall
# name:  Bar id:  13003
# (2904, 13)
#
# ===============================
# station:  Keefer & Columbia
# name:  Bar id:  13003
# (3010, 13)
#
# ===============================
# station:  Marinaside & Cooperage
# name:  Bar id:  13003
# (3118, 13)
#
# ===============================
# station:  Bidwell & Burnaby
# name:  Bar id:  13003
# (3159, 13)
#
# ===============================
# station:  Robson & Granville
# name:  Bar id:  13003
# (3275, 13)
#
# ===============================
# station:  Expo & Smithe
# name:  Bar id:  13003
# (3390, 13)
#
# ===============================
# station:  Cypress & Cornwall
# name:  Bar id:  13003
# (3438, 13)
#
# ===============================
# station:  Anderson & 2nd
# name:  Bar id:  13003
# (3487, 13)
#
# ===============================
# station:  7th & Granville
# name:  Bar id:  13003
# (3529, 13)
#
# ===============================
# station:  10th & Granville
# name:  Bar id:  13003
# (3562, 13)
#
# ===============================
# station:  14th & Granville
# name:  Bar id:  13003
# (3584, 13)
#
# ===============================
# station:  14th & Cambie
# name:  Bar id:  13003
# (3608, 13)
#
# ===============================
# station:  Ontario & 5th
# name:  Bar id:  13003
# (3681, 13)
#
# ===============================
# station:  10th & Main
# name:  Bar id:  13003
# (3760, 13)
#
# ===============================
# station:  Cypress & 4th
# name:  Bar id:  13003
# (3815, 13)
#
# ===============================
# station:  Vanier Park
# name:  Bar id:  13003
# (3856, 13)
#
# ===============================
# station:  Nelson & Mainland
# name:  Bar id:  13003
# (3970, 13)
#
# ===============================
# station:  Nelson & Richards
# name:  Bar id:  13003
# (4079, 13)
#
# ===============================
# station:  7th & Heather
# name:  Bar id:  13003
# (4111, 13)
#
# ===============================
# station:  Harwood & Bute
# name:  Bar id:  13003
# (4212, 13)
#
# ===============================
# station:  Chilco & Barclay
# name:  Bar id:  13003
# (4250, 13)
#
# ===============================
# station:  Chilco & Robson
# name:  Bar id:  13003
# (4289, 13)
#
# ===============================
# station:  Nicola & Robson
# name:  Bar id:  13003
# (4382, 13)
#
# ===============================
# station:  Carrall & Hastings
# name:  Bar id:  13003
# (4490, 13)
#
# ===============================
# station:  šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery
# name:  Bar id:  13003
# (4606, 13)
#
# ===============================
# station:  Stanley Park - Vancouver Aquarium
# name:  Bar id:  13003
# (4618, 13)
#
# ===============================
# station:  Stanley Park - Second Beach North
# name:  Bar id:  13003
# (4624, 13)
#
# ===============================
# station:  Stanley Park - Second Beach South
# name:  Bar id:  13003
# (4638, 13)
#
# ===============================
# station:  Stanley Park - Totem Poles
# name:  Bar id:  13003
# (4652, 13)
#
# ===============================
# station:  Heather & 14th
# name:  Bar id:  13003
# (4672, 13)
#
# ===============================
# station:  8th & Ontario
# name:  Bar id:  13003
# (4750, 13)
#
# ===============================
# station:  1st & Chestnut
# name:  Bar id:  13003
# (4808, 13)
#
# ===============================
# station:  7th & Arbutus
# name:  Bar id:  13003
# (4852, 13)
#
# ===============================
# station:  5th & Arbutus
# name:  Bar id:  13003
# (4896, 13)
#
# ===============================
# station:  10th & Oak
# name:  Bar id:  13003
# (4917, 13)
#
# ===============================
# station:  Arbutus & 16th
# name:  Bar id:  13003
# (4930, 13)
#
# ===============================
# station:  Cypress & 14th
# name:  Bar id:  13003
# (4957, 13)
#
# ===============================
# station:  Cypress & 16th
# name:  Bar id:  13003
# (4978, 13)
#
# ===============================
# station:  Georgia & Thurlow
# name:  Bar id:  13003
# (5083, 13)
#
# ===============================
# station:  Thurlow & Pendrell
# name:  Bar id:  13003
# (5187, 13)
#
# ===============================
# station:  Heather & 16th
# name:  Bar id:  13003
# (5205, 13)
#
# ===============================
# station:  14th & Ontario
# name:  Bar id:  13003
# (5268, 13)
#
# ===============================
# station:  14th & Main
# name:  Bar id:  13003
# (5330, 13)
#
# ===============================
# station:  David Lam Park - West
# name:  Bar id:  13003
# (5428, 13)
#
# ===============================
# station:  Beach & Seymour
# name:  Bar id:  13003
# (5533, 13)
#
# ===============================
# station:  Richards & Helmcken
# name:  Bar id:  13003
# (5641, 13)
#
# ===============================
# station:  Burrard & 4th
# name:  Bar id:  13003
# (5705, 13)
#
# ===============================
# station:  Burrard & 7th
# name:  Bar id:  13003
# (5759, 13)
#
# ===============================
# station:  South False Creek Seawall
# name:  Bar id:  13003
# (5839, 13)
#
# ===============================
# station:  Chestnut & McNicoll
# name:  Bar id:  13003
# (5879, 13)
#
# ===============================
# station:  Creekside Park North
# name:  Bar id:  13003
# (5983, 13)
#
# ===============================
# station:  Alexander & Main
# name:  Bar id:  13003
# (6089, 13)
#
# ===============================
# station:  Arbutus Greenway & 14th
# name:  Bar id:  13003
# (6106, 13)
#
# ===============================
# station:  Arbutus Greenway & Fir
# name:  Bar id:  13003
# (6150, 13)
#
# ===============================
# station:  Kitsilano Beach Park
# name:  Bar id:  13003
# (6174, 13)
#
# ===============================
# station:  Arbutus & McNicoll
# name:  Bar id:  13003
# (6195, 13)
#
# ===============================
# station:  Vine & 4th
# name:  Bar id:  13003
# (6235, 13)
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Bar id:  13003
# (6339, 13)
#
# ===============================
# station:  Alder & 11th
# name:  Bar id:  13003
# (6361, 13)
#
# ===============================
# station:  10th & Columbia
# name:  Bar id:  13003
# (6448, 13)
#
# ===============================
# station:  1st & Manitoba
# name:  Bar id:  13003
# (6538, 13)
#
# ===============================
# station:  10th & Ontario
# name:  Bar id:  13003
# (6618, 13)
#
# ===============================
# station:  Quebec & 1st
# name:  Bar id:  13003
# (6701, 13)
#
# ===============================
# station:  Columbia & 14th
# name:  Bar id:  13003
# (6766, 13)
#
# ===============================
# station:  Bute & Davie
# name:  Bar id:  13003
# (6867, 13)
#
# ===============================
# station:  7th & Laurel
# name:  Bar id:  13003
# (6903, 13)
#
# ===============================
# station:  7th &  Alder
# name:  Bar id:  13003
# (6946, 13)
#
# ===============================
# station:  Science World
# name:  Bar id:  13003
# (7039, 13)
#
# ===============================
# station:  1st & Scotia
# name:  Bar id:  13003
# (7113, 13)
#
# ===============================
# station:  Georgia & Main
# name:  Bar id:  13003
# (7218, 13)
#
# ===============================
# station:  Shaw Tower
# name:  Bar id:  13003
# (7326, 13)
#
# ===============================
# station:  Pine & 14th
# name:  Bar id:  13003
# (7348, 13)
#
# ===============================
# station:  York & Yew
# name:  Bar id:  13003
# (7381, 13)
#
# ===============================
# station:  Pine & 10th
# name:  Bar id:  13003
# (7414, 13)
#
# ===============================
# station:  8th & Scotia
# name:  Bar id:  13003
# (7490, 13)
#
# ===============================
# station:  Alberni & Jervis
# name:  Bar id:  13003
# (7596, 13)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Bar id:  13003
# (7608, 13)
#
# ===============================
# station:  14th & Alder
# name:  Bar id:  13003
# (7620, 13)
#
# ===============================
# station:  Pender & Gore
# name:  Bar id:  13003
# (7725, 13)
#
# ===============================
# station:  Carrall & Seawall
# name:  Bar id:  13003
# (7833, 13)
#
# ===============================
# station:  Glen & Union
# name:  Bar id:  13003
# (7866, 13)
#
# ===============================
# station:  Adanac & McLean
# name:  Bar id:  13003
# (7919, 13)
#
# ===============================
# station:  Commercial & Adanac
# name:  Bar id:  13003
# (7974, 13)
#
# ===============================
# station:  Pender & Commercial
# name:  Bar id:  13003
# (8016, 13)
#
# ===============================
# station:  Keefer & Princess
# name:  Bar id:  13003
# (8085, 13)
#
# ===============================
# station:  Alexander & Railway
# name:  Bar id:  13003
# (8162, 13)
#
# ===============================
# station:  Napier & Commercial
# name:  Bar id:  13003
# (8199, 13)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Bar id:  13003
# (8248, 13)
#
# ===============================
# station:  Thornton & National
# name:  Bar id:  13003
# (8300, 13)
#
# ===============================
# station:  Keith & 6th
# name:  Bar id:  13003
# (8330, 13)
#
# ===============================
# station:  Glen & 6th
# name:  Bar id:  13003
# (8349, 13)
#
# ===============================
# station:  Grant & Commercial
# name:  Bar id:  13003
# (8383, 13)
#
# ===============================
# station:  2nd & Commercial
# name:  Bar id:  13003
# (8417, 13)
#
# ===============================
# station:  4th & Commercial
# name:  Bar id:  13003
# (8451, 13)
#
# ===============================
# station:  8th & Commercial
# name:  Bar id:  13003
# (8478, 13)
#
# ===============================
# station:  10th & Commercial
# name:  Bar id:  13003
# (8495, 13)
#
# ===============================
# station:  Woodland & 10th
# name:  Bar id:  13003
# (8506, 13)
#
# ===============================
# station:  Glen & Broadway
# name:  Bar id:  13003
# (8525, 13)
#
# ===============================
# station:  St George & Broadway
# name:  Bar id:  13003
# (8587, 13)
#
# ===============================
# station:  7th & Woodland
# name:  Bar id:  13003
# (8617, 13)
#
# ===============================
# station:  Woodland & 4th
# name:  Bar id:  13003
# (8649, 13)
#
# ===============================
# station:  Woodland & Graveley
# name:  Bar id:  13003
# (8686, 13)
#
# ===============================
# station:  Charles & Woodland
# name:  Bar id:  13003
# (8722, 13)
#
# ===============================
# station:  18th & Main
# name:  Bar id:  13003
# (8777, 13)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Bar id:  13003
# (8837, 13)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Bar id:  13003
# (8899, 13)
#
# ===============================
# station:  13th & St George
# name:  Bar id:  13003
# (8957, 13)
#
# ===============================
# station:  10th & Fraser
# name:  Bar id:  13003
# (9009, 13)
#
# ===============================
# station:  8th & Fraser
# name:  Bar id:  13003
# (9056, 13)
#
# ===============================
# station:  St Catherines & 10th
# name:  Bar id:  13003
# (9078, 13)
#
# ===============================
# station:  St Catherines & 7th
# name:  Bar id:  13003
# (9096, 13)
#
# ===============================
# station:  Pender & Victoria
# name:  Bar id:  13003
# (9138, 13)
#
# ===============================
# station:  Victoria & 4th
# name:  Bar id:  13003
# (9169, 13)
#
# ===============================
# station:  Victoria & 10th
# name:  Bar id:  13003
# (9182, 13)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Bar id:  13003
# (9191, 13)
#
# ===============================
# station:  Triumph & Victoria
# name:  Bar id:  13003
# (9226, 13)
#
# ===============================
# station:  Windsor & 14th
# name:  Bar id:  13003
# (9246, 13)
#
# ===============================
# station:  14th & Fraser
# name:  Bar id:  13003
# (9292, 13)
#
# ===============================
# station:  15th & Knight
# name:  Bar id:  13003
# (9302, 13)
#
# ===============================
# station:  Commercial & Pandora
# name:  Bar id:  13003
# (9336, 13)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Bar id:  13003
# (9383, 13)
#
# ===============================
# station:  6th & Prince Edward
# name:  Bar id:  13003
# (9447, 13)
#
# ===============================
# station:  6th & Carolina
# name:  Bar id:  13003
# (9493, 13)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Bar id:  13003
# (9493, 13)
#
# ===============================
# station:  Union & Dunlevy
# name:  Bar id:  13003
# (9587, 13)
#
# ===============================
# station:  Keefer & Hawks
# name:  Bar id:  13003
# (9648, 13)
#
# ===============================
# station:  Hawks & Union
# name:  Bar id:  13003
# (9703, 13)
#
# ===============================
# station:  Charles & Commercial
# name:  Bar id:  13003
# (9738, 13)
#
# ===============================
# station:  10th & Kingsway
# name:  Bar id:  13003
# (9805, 13)
#
# ===============================
# station:  Beach & Hornby
# name:  Bar id:  13003
# (9909, 13)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Bar id:  13003
# (10018, 13)
#
# ===============================
# station:  Bute & Barclay
# name:  Bar id:  13003
# (10125, 13)
#
# ===============================
# station:  8th & Yukon
# name:  Bar id:  13003
# (10193, 13)
#
# ===============================
# station:  Princess & Union
# name:  Bar id:  13003
# (10257, 13)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Bar id:  13003
# (10375, 13)
#
# ===============================
# station:  5th & Main
# name:  Bar id:  13003
# (10455, 13)
#
# ===============================
# station:  3rd & Quebec
# name:  Bar id:  13003
# (10531, 13)
#
# ===============================
# station:  Richards & Cordova
# name:  Bar id:  13003
# (10645, 13)
#
# ===============================
# station:  Richards & Robson
# name:  Bar id:  13003
# (10764, 13)
#
# ===============================
# station:  Olympic Village Station
# name:  Bar id:  13003
# (10806, 13)
#
# ===============================
# station:  Campbell & Hastings
# name:  Bar id:  13003
# (10842, 13)
#
# ===============================
# station:  Cardero & Davie
# name:  Bar id:  13003
# (10898, 13)
#
# ===============================
# station:  Aquatic Centre
# name:  Bar id:  13003
# (10968, 13)
#
# ===============================
# station:  Beach & Broughton
# name:  Bar id:  13003
# (11018, 13)
#
# ===============================
# station:  Beach & Cardero
# name:  Bar id:  13003
# (11061, 13)
#
# ===============================
# station:  Georgia & Homer
# name:  Bar id:  13003
# (11178, 13)
#
# ===============================
# station:  Columbia & 5th
# name:  Bar id:  13003
# (11247, 13)
#
# ===============================
# station:  Haro & Denman
# name:  Bar id:  13003
# (11302, 13)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Bar id:  13003
# (11302, 13)
#
# ===============================
# station:  Arbutus & 10th
# name:  Bar id:  13003
# (11340, 13)
#
# ===============================
# station:  Ontario & 16th
# name:  Bar id:  13003
# (11404, 13)
#
# ===============================
# station:  Richards & Davie
# name:  Bar id:  13003
# (11515, 13)
#
# ===============================
# station:  8th & Prince Edward
# name:  Bar id:  13003
# (11579, 13)
#
# ===============================
# station:  Jervis & Robson
# name:  Bar id:  13003
# (11685, 13)
#
# ===============================
# station:  Smithe & Burrard
# name:  Bar id:  13003
# (11797, 13)
#
# ===============================
# station:  Broughton & Davie
# name:  Bar id:  13003
# (11862, 13)
#
# ===============================
# station:  Cypress & 10th
# name:  Bar id:  13003
# (11896, 13)
#
# ===============================
# station:  Granville Island
# name:  Bar id:  13003
# (11954, 13)
#
# ===============================
# station:  McLean & Pender
# name:  Bar id:  13003
# (11997, 13)
#
# ===============================
# station:  Richards & Smithe
# name:  Bar id:  13003
# (12112, 13)
#
# ===============================
# station:  Bute & Robson
# name:  Bar id:  13003
# (12217, 13)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Bar id:  13003
# (12237, 13)
#
# ===============================
# station:  Alma & Point Grey
# name:  Bar id:  13003
# (12245, 13)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Bar id:  13003
# (12269, 13)
#
# ===============================
# station:  Hastings & Broughton
# name:  Bar id:  13003
# (12356, 13)
#
# ===============================
# station:  Yew & Broadway
# name:  Bar id:  13003
# (12394, 13)
#
# ===============================
# station:  8th & Macdonald
# name:  Bar id:  13003
# (12423, 13)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Bar id:  13003
# (12450, 13)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Bar id:  13003
# (12468, 13)
#
# ===============================
# station:  Grandview & Commercial
# name:  Bar id:  13003
# (12495, 13)
#
# ===============================
# station:  14th & Oak
# name:  Bar id:  13003
# (12514, 13)
#
# ===============================
# station:  Wallace & 4th
# name:  Bar id:  13003
# (12522, 13)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Bar id:  13003
# (12549, 13)
#
# ===============================
# station:  Balaclava & 6th
# name:  Bar id:  13003
# (12576, 13)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Bar id:  13003
# (12603, 13)
#
# ===============================
# station:  Dunbar & 6th
# name:  Bar id:  13003
# (12624, 13)
#
# ===============================
# station:  18th & Cambie
# name:  Bar id:  13003
# (12635, 13)
#
# ===============================
# station:  Blenheim & 4th
# name:  Bar id:  13003
# (12662, 13)
#
# ===============================
# station:  18th & Heather
# name:  Bar id:  13003
# (12673, 13)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Bar id:  13003
# (12694, 13)
#
# ===============================
# station:  20th & Main
# name:  Bar id:  13003
# (12739, 13)
#
# ===============================
# station:  Station & Terminal
# name:  Bar id:  13003
# (12802, 13)
#
# ===============================
# station:  Jericho Beach
# name:  Bar id:  13003
# (12808, 13)
#
# ===============================
# station:  Burrard & Drake
# name:  Bar id:  13003
# (12913, 13)
#
# ===============================
# station:  Columbia & 1st
# name:  Bar id:  13003
# (12999, 13)
#
# ===============================
# station:  Davie & Beach
# name:  Bar id:  13003
# (13039, 13)
#
# ===============================
# station:  Morton & Denman
# name:  Bar id:  13003
# (13078, 13)
#
# ===============================
# station:  13th & Cambie
# name:  Bar id:  13003
# (13108, 13)
#
# ===============================
# station:  Nelson & Denman
# name:  Bar id:  13003
# (13166, 13)
#
# ===============================
# station:  Melville & Bute
# name:  Bar id:  13003
# (13269, 13)
#
# ===============================
# station:  Seymour & Cordova
# name:  Bar id:  13003
# (13380, 13)
#
# ===============================
# station:  Arbutus & Nanton
# name:  Bar id:  13003
# (13381, 13)
#
# ===============================
# station:  Yukon & 6th
# name:  Bar id:  13003
# (13440, 13)
#
# ===============================
# station:  11th & Kingsway
# name:  Bar id:  13003
# (13502, 13)
#
# ===============================
# station:  Wylie & 2nd
# name:  Bar id:  13003
# (13565, 13)
#
# ===============================
# station:  29th & Cambie
# name:  Bar id:  13003
# (13565, 13)
#
# ===============================
# station:  Rolston & Granville
# name:  Bar id:  13003
# (13668, 13)
#
# ===============================
# station:  East Blvd & 37th
# name:  Bar id:  13003
# (13671, 13)
#
# ===============================
# station:  28th & Willow
# name:  Bar id:  13003
# (13671, 13)
#
# ===============================
# station:  Ontario & 23rd
# name:  Bar id:  13003
# (13697, 13)
#
# ===============================
# station:  30th & Ontario
# name:  Bar id:  13003
# (13715, 13)
#
# ===============================
# station:  Franklin & Nanaimo
# name:  Bar id:  13003
# (13737, 13)
#
# ===============================
# station:  Lakewood & Triumph
# name:  Bar id:  13003
# (13767, 13)
#
# ===============================
# station:  Wall & Eton
# name:  Bar id:  13003
# (13788, 13)
#
# ===============================
# station:  Lakewood & Oxford
# name:  Bar id:  13003
# (13818, 13)
#
# ===============================
# station:  22nd & Cambie
# name:  Bar id:  13003
# (13824, 13)
#
# ===============================
# station:  King Edward & Cambie
# name:  Bar id:  13003
# (13830, 13)
#
# ===============================
# station:  Heather & 29th
# name:  Bar id:  13003
# (13830, 13)
#
# ===============================
# station:  Cardero & Robson
# name:  Bar id:  13003
# (13917, 13)
#
# ===============================
# station:  Commercial & 20th
# name:  Bar id:  13003
# (13923, 13)
#
# ===============================
# station:  Hornby & Drake
# name:  Bar id:  13003
# (14025, 13)
#
# ===============================
# station:  Burrard & 14th
# name:  Bar id:  13003
# (14053, 13)
#
# ===============================
# name:  Park id:  16032
#
# ===============================
# station:  10th & Cambie
# name:  Park id:  16032
# (13, 13)
#
# ===============================
# station:  Yaletown-Roundhouse Station
# name:  Park id:  16032
# (35, 13)
#
# ===============================
# station:  Dunsmuir & Beatty
# name:  Park id:  16032
# (56, 13)
#
# ===============================
# station:  12th & Yukon (City Hall)
# name:  Park id:  16032
# (68, 13)
#
# ===============================
# station:  8th & Ash
# ...
# name:  Parking id:  19020
# (1488, 13)
#
# ===============================
# station:  South False Creek Seawall
# name:  Parking id:  19020
# (1497, 13)
#
# ===============================
# station:  Chestnut & McNicoll
# name:  Parking id:  19020
# (1499, 13)
#
# ===============================
# station:  Creekside Park North
# name:  Parking id:  19020
# (1518, 13)
#
# ===============================
# station:  Alexander & Main
# name:  Parking id:  19020
# (1542, 13)
#
# ===============================
# station:  Arbutus Greenway & 14th
# name:  Parking id:  19020
# (1542, 13)
#
# ===============================
# station:  Arbutus Greenway & Fir
# name:  Parking id:  19020
# (1547, 13)
#
# ===============================
# station:  Kitsilano Beach Park
# name:  Parking id:  19020
# (1547, 13)
#
# ===============================
# station:  Arbutus & McNicoll
# name:  Parking id:  19020
# (1547, 13)
#
# ===============================
# station:  Vine & 4th
# name:  Parking id:  19020
# (1547, 13)
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Parking id:  19020
# (1555, 13)
#
# ===============================
# station:  Alder & 11th
# name:  Parking id:  19020
# (1562, 13)
#
# ===============================
# station:  10th & Columbia
# name:  Parking id:  19020
# (1568, 13)
#
# ===============================
# station:  1st & Manitoba
# name:  Parking id:  19020
# (1576, 13)
#
# ===============================
# station:  10th & Ontario
# name:  Parking id:  19020
# (1580, 13)
#
# ===============================
# station:  Quebec & 1st
# name:  Parking id:  19020
# (1587, 13)
#
# ===============================
# station:  Columbia & 14th
# name:  Parking id:  19020
# (1592, 13)
#
# ===============================
# station:  Bute & Davie
# name:  Parking id:  19020
# (1613, 13)
#
# ===============================
# station:  7th & Laurel
# name:  Parking id:  19020
# (1620, 13)
#
# ===============================
# station:  7th &  Alder
# name:  Parking id:  19020
# (1629, 13)
#
# ===============================
# station:  Science World
# name:  Parking id:  19020
# (1644, 13)
#
# ===============================
# station:  1st & Scotia
# name:  Parking id:  19020
# (1646, 13)
#
# ===============================
# station:  Georgia & Main
# name:  Parking id:  19020
# (1666, 13)
#
# ===============================
# station:  Shaw Tower
# name:  Parking id:  19020
# (1711, 13)
#
# ===============================
# station:  Pine & 14th
# name:  Parking id:  19020
# (1714, 13)
#
# ===============================
# station:  York & Yew
# name:  Parking id:  19020
# (1714, 13)
#
# ===============================
# station:  Pine & 10th
# name:  Parking id:  19020
# (1718, 13)
#
# ===============================
# station:  8th & Scotia
# name:  Parking id:  19020
# (1720, 13)
#
# ===============================
# station:  Alberni & Jervis
# name:  Parking id:  19020
# (1750, 13)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Parking id:  19020
# (1753, 13)
#
# ===============================
# station:  14th & Alder
# name:  Parking id:  19020
# (1760, 13)
#
# ===============================
# station:  Pender & Gore
# name:  Parking id:  19020
# (1776, 13)
#
# ===============================
# station:  Carrall & Seawall
# name:  Parking id:  19020
# (1804, 13)
#
# ===============================
# station:  Glen & Union
# name:  Parking id:  19020
# (1804, 13)
#
# ===============================
# station:  Adanac & McLean
# name:  Parking id:  19020
# (1804, 13)
#
# ===============================
# station:  Commercial & Adanac
# name:  Parking id:  19020
# (1804, 13)
#
# ===============================
# station:  Pender & Commercial
# name:  Parking id:  19020
# (1804, 13)
#
# ===============================
# station:  Keefer & Princess
# name:  Parking id:  19020
# (1807, 13)
#
# ===============================
# station:  Alexander & Railway
# name:  Parking id:  19020
# (1810, 13)
#
# ===============================
# station:  Napier & Commercial
# name:  Parking id:  19020
# (1810, 13)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Parking id:  19020
# (1810, 13)
#
# ===============================
# station:  Thornton & National
# name:  Parking id:  19020
# (1814, 13)
#
# ===============================
# station:  Keith & 6th
# name:  Parking id:  19020
# (1815, 13)
#
# ===============================
# station:  Glen & 6th
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  Grant & Commercial
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  2nd & Commercial
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  4th & Commercial
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  8th & Commercial
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  10th & Commercial
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  Woodland & 10th
# name:  Parking id:  19020
# (1816, 13)
#
# ===============================
# station:  Glen & Broadway
# name:  Parking id:  19020
# (1817, 13)
#
# ===============================
# station:  St George & Broadway
# name:  Parking id:  19020
# (1819, 13)
#
# ===============================
# station:  7th & Woodland
# name:  Parking id:  19020
# (1819, 13)
#
# ===============================
# station:  Woodland & 4th
# name:  Parking id:  19020
# (1819, 13)
#
# ===============================
# station:  Woodland & Graveley
# name:  Parking id:  19020
# (1819, 13)
#
# ===============================
# station:  Charles & Woodland
# name:  Parking id:  19020
# (1819, 13)
#
# ===============================
# station:  18th & Main
# name:  Parking id:  19020
# (1820, 13)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Parking id:  19020
# (1821, 13)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Parking id:  19020
# (1822, 13)
#
# ===============================
# station:  13th & St George
# name:  Parking id:  19020
# (1824, 13)
#
# ===============================
# station:  10th & Fraser
# name:  Parking id:  19020
# (1826, 13)
#
# ===============================
# station:  8th & Fraser
# name:  Parking id:  19020
# (1828, 13)
#
# ===============================
# station:  St Catherines & 10th
# name:  Parking id:  19020
# (1830, 13)
#
# ===============================
# station:  St Catherines & 7th
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  Pender & Victoria
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  Victoria & 4th
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  Victoria & 10th
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  Triumph & Victoria
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  Windsor & 14th
# name:  Parking id:  19020
# (1832, 13)
#
# ===============================
# station:  14th & Fraser
# name:  Parking id:  19020
# (1833, 13)
#
# ===============================
# station:  15th & Knight
# name:  Parking id:  19020
# (1834, 13)
#
# ===============================
# station:  Commercial & Pandora
# name:  Parking id:  19020
# (1834, 13)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Parking id:  19020
# (1836, 13)
#
# ===============================
# station:  6th & Prince Edward
# name:  Parking id:  19020
# (1838, 13)
#
# ===============================
# station:  6th & Carolina
# name:  Parking id:  19020
# (1840, 13)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Parking id:  19020
# (1840, 13)
#
# ===============================
# station:  Union & Dunlevy
# name:  Parking id:  19020
# (1849, 13)
#
# ===============================
# station:  Keefer & Hawks
# name:  Parking id:  19020
# (1851, 13)
#
# ===============================
# station:  Hawks & Union
# name:  Parking id:  19020
# (1853, 13)
#
# ===============================
# station:  Charles & Commercial
# name:  Parking id:  19020
# (1853, 13)
#
# ===============================
# station:  10th & Kingsway
# name:  Parking id:  19020
# (1855, 13)
#
# ===============================
# station:  Beach & Hornby
# name:  Parking id:  19020
# (1862, 13)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Parking id:  19020
# (1912, 13)
#
# ===============================
# station:  Bute & Barclay
# name:  Parking id:  19020
# (1944, 13)
#
# ===============================
# station:  8th & Yukon
# name:  Parking id:  19020
# (1950, 13)
#
# ===============================
# station:  Princess & Union
# name:  Parking id:  19020
# (1953, 13)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Parking id:  19020
# (2003, 13)
#
# ===============================
# station:  5th & Main
# name:  Parking id:  19020
# (2006, 13)
#
# ===============================
# station:  3rd & Quebec
# name:  Parking id:  19020
# (2009, 13)
#
# ===============================
# station:  Richards & Cordova
# name:  Parking id:  19020
# (2059, 13)
#
# ===============================
# station:  Richards & Robson
# name:  Parking id:  19020
# (2109, 13)
#
# ===============================
# station:  Olympic Village Station
# name:  Parking id:  19020
# (2116, 13)
#
# ===============================
# station:  Campbell & Hastings
# name:  Parking id:  19020
# (2117, 13)
#
# ===============================
# station:  Cardero & Davie
# name:  Parking id:  19020
# (2124, 13)
#
# ===============================
# station:  Aquatic Centre
# name:  Parking id:  19020
# (2129, 13)
#
# ===============================
# station:  Beach & Broughton
# name:  Parking id:  19020
# (2132, 13)
#
# ===============================
# station:  Beach & Cardero
# name:  Parking id:  19020
# (2134, 13)
#
# ===============================
# station:  Georgia & Homer
# name:  Parking id:  19020
# (2184, 13)
#
# ===============================
# station:  Columbia & 5th
# name:  Parking id:  19020
# (2189, 13)
#
# ===============================
# station:  Haro & Denman
# name:  Parking id:  19020
# (2196, 13)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Parking id:  19020
# (2196, 13)
#
# ===============================
# station:  Arbutus & 10th
# name:  Parking id:  19020
# (2197, 13)
#
# ===============================
# station:  Ontario & 16th
# name:  Parking id:  19020
# (2199, 13)
#
# ===============================
# station:  Richards & Davie
# name:  Parking id:  19020
# (2218, 13)
#
# ===============================
# station:  8th & Prince Edward
# name:  Parking id:  19020
# (2220, 13)
#
# ===============================
# station:  Jervis & Robson
# name:  Parking id:  19020
# (2247, 13)
#
# ===============================
# station:  Smithe & Burrard
# name:  Parking id:  19020
# (2292, 13)
#
# ===============================
# station:  Broughton & Davie
# name:  Parking id:  19020
# (2305, 13)
#
# ===============================
# station:  Cypress & 10th
# name:  Parking id:  19020
# (2308, 13)
#
# ===============================
# station:  Granville Island
# name:  Parking id:  19020
# (2313, 13)
#
# ===============================
# station:  McLean & Pender
# name:  Parking id:  19020
# (2313, 13)
#
# ===============================
# station:  Richards & Smithe
# name:  Parking id:  19020
# (2363, 13)
#
# ===============================
# station:  Bute & Robson
# name:  Parking id:  19020
# (2400, 13)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Parking id:  19020
# (2400, 13)
#
# ===============================
# station:  Alma & Point Grey
# name:  Parking id:  19020
# (2400, 13)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Parking id:  19020
# (2400, 13)
#
# ===============================
# station:  Hastings & Broughton
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  Yew & Broadway
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  8th & Macdonald
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  Grandview & Commercial
# name:  Parking id:  19020
# (2421, 13)
#
# ===============================
# station:  14th & Oak
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  Wallace & 4th
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  Balaclava & 6th
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  Dunbar & 6th
# name:  Parking id:  19020
# (2429, 13)
#
# ===============================
# station:  18th & Cambie
# name:  Parking id:  19020
# (2432, 13)
#
# ===============================
# station:  Blenheim & 4th
# name:  Parking id:  19020
# (2432, 13)
#
# ===============================
# station:  18th & Heather
# name:  Parking id:  19020
# (2436, 13)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Parking id:  19020
# (2436, 13)
#
# ===============================
# station:  20th & Main
# name:  Parking id:  19020
# (2436, 13)
#
# ===============================
# station:  Station & Terminal
# name:  Parking id:  19020
# (2443, 13)
#
# ===============================
# station:  Jericho Beach
# name:  Parking id:  19020
# (2443, 13)
#
# ===============================
# station:  Burrard & Drake
# name:  Parking id:  19020
# (2459, 13)
#
# ===============================
# station:  Columbia & 1st
# name:  Parking id:  19020
# (2469, 13)
#
# ===============================
# station:  Davie & Beach
# name:  Parking id:  19020
# (2472, 13)
#
# ===============================
# station:  Morton & Denman
# name:  Parking id:  19020
# (2475, 13)
#
# ===============================
# station:  13th & Cambie
# name:  Parking id:  19020
# (2481, 13)
#
# ===============================
# station:  Nelson & Denman
# name:  Parking id:  19020
# (2487, 13)
#
# ===============================
# station:  Melville & Bute
# name:  Parking id:  19020
# (2530, 13)
#
# ===============================
# station:  Seymour & Cordova
# name:  Parking id:  19020
# (2580, 13)
#
# ===============================
# station:  Arbutus & Nanton
# name:  Parking id:  19020
# (2581, 13)
#
# ===============================
# station:  Yukon & 6th
# name:  Parking id:  19020
# (2587, 13)
#
# ===============================
# station:  11th & Kingsway
# name:  Parking id:  19020
# (2589, 13)
#
# ===============================
# station:  Wylie & 2nd
# name:  Parking id:  19020
# (2597, 13)
#
# ===============================
# station:  29th & Cambie
# name:  Parking id:  19020
# (2598, 13)
#
# ===============================
# station:  Rolston & Granville
# name:  Parking id:  19020
# (2608, 13)
#
# ===============================
# station:  East Blvd & 37th
# name:  Parking id:  19020
# (2608, 13)
#
# ===============================
# station:  28th & Willow
# name:  Parking id:  19020
# (2609, 13)
#
# ===============================
# station:  Ontario & 23rd
# name:  Parking id:  19020
# (2609, 13)
#
# ===============================
# station:  30th & Ontario
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  Franklin & Nanaimo
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  Lakewood & Triumph
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  Wall & Eton
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  Lakewood & Oxford
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  22nd & Cambie
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  King Edward & Cambie
# name:  Parking id:  19020
# (2610, 13)
#
# ===============================
# station:  Heather & 29th
# name:  Parking id:  19020
# (2611, 13)
#
# ===============================
# station:  Cardero & Robson
# name:  Parking id:  19020
# (2627, 13)
#
# ===============================
# station:  Commercial & 20th
# name:  Parking id:  19020
# (2628, 13)
#
# ===============================
# station:  Hornby & Drake
# name:  Parking id:  19020
# (2647, 13)
#
# ===============================
# station:  Burrard & 14th
# name:  Parking id:  19020
# (2650, 13)
#
# FS loop Done!

# %%
# read back the csv files, into dataframe with the same name as the csv file name

# Find all the names under the data_path and like 'POI_FS_*.csv'
file_name_list_FS = !ls $data_path | grep 'POI_FS_.*.csv'

# create a list of dataframes, named as POI_FS_* and read the corresponding csv files
for file in file_name_list_FS:
    shape_of_it = None
    # print the file path and name
    print(file[:-4]) # .replace(' ', '_')[:-4])
    # create a dataframe named as file.replace(' ', '_')
    # read the csv file with the file name, withou the '.csv' surfix
    try:
        exec(file[:-4] + ' = pd.read_csv(data_path+file)')
        # check the shape of the dataframe, save to a variable named as shape_of_it
        exec('shape_of_it = '+file[:-4]+'.shape')
        print('shape_of_it: ', shape_of_it)    
        # if shape_of_it is NoneType, then print the error message
        if shape_of_it[0] == 0:
            print('\033[1;31m' + file[:-4] + ' is Empty!' + '\033[0m')
    except:
        print('Error code: ', sys.exc_info()[0])
        print('\033[1;31m' + file[:-4] + ' is Empty!' + '\033[0m')
# Out:
# POI_FS_Bar_13003
# shape_of_it:  (14053, 13)
# POI_FS_EV_Charging_Station_19006
# shape_of_it:  (156, 13)
# POI_FS_Fuel_Station_19007
# shape_of_it:  (824, 13)
# POI_FS_Park_16032
# shape_of_it:  (3739, 13)
# POI_FS_Parking_19020
# shape_of_it:  (2650, 13)
# POI_FS_Restaurant_13065
# shape_of_it:  (21012, 13)
# POI_FS_Transport_Hub_19030
# shape_of_it:  (4996, 13)

# %%
# There do exist some stations that do not have any POIs in certain categories around them, so the dataframes are not empty. 
# This need to be noticed when doing the analysis.

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# define the task:

# define a dictionary to store the POIs around each station
# since each POI may have multiple categories from the API, we will use the self-defined category_name as well
# documentation here: https://docs.developer.yelp.com/docs/resources-categories

# Restaurants (restaurants, All)
# Bars (bars, All)
# Parks (parks, All)
# Transportation (transport, All)
# Gas Stations (servicestations, All)
# EV Charging Stations (evchargingstations, All)
# Parking (parking, All)

dict_POI_yelp = {'Restaurant': 'restaurants, All', 'Bar': 'bars, All', 'Park': 'parks, All', 
                 'Transport Hub': 'transport, All', 'Fuel Station': 'servicestations, All', 'EV Charging Station': 'evchargingstations, All', 'Parking': 'parking, All'}


# define the radius and number of returns for each query
radius_value = 1000
return_limit = 50

# %%
# declare global variables
global api_key_yelp

api_key_yelp = pd.read_csv('~/yelp api key.csv', header=None).values[0][0]

api_key_yelp = "Bearer " + api_key_yelp

# %%
# read the target city's stations from the prvious step:
# DF_target_city_stations from the csv file
DF_target_city_stations = pd.read_csv(data_path+'target_city_stations_DF.csv')

# %%
def get_venues_ll_category_yelp(latitude, longitude ,category, radius_value=1000,result_limit=50):
    '''
    This function is to query the venues around a given latitude and longitude, with a given category
    
    Parameters:
    latitude: float, the latitude of the location
    longitude: float, the longitude of the location
    radius_value: int, the radius of the query, in meters
    result_limit: int, the number of results to return, max is 50
    
    Reference:
    https://docs.developer.yelp.com/reference/v3_business_search
    https://docs.developer.yelp.com/docs/resources-categories

    # Restaurants (restaurants, All)
    # Bars (bars, All)
    # Parks (parks, All)
    # Transportation (transport, All)
    # Gas Stations (servicestations, All)
    # EV Charging Stations (evchargingstations, All)    
    # Parking (parking, All)
    
    Example:
    get_venues_ll_category_yelp(40.730610, -73.935242, 'bars, All', 1000, 50)
    '''    
    
    
    URL = "https://api.yelp.com/v3/businesses/search?"

    headers = {
        "accept": "application/json",
        "Authorization": api_key_yelp
    }
    params = {}
    params['latitude'] = latitude
    params['longitude'] = longitude
    params['radius'] = radius_value
    params['categories'] = category 
    params['limit'] = result_limit
    params['sort_by'] =  'distance' # 'best_match' # 'rating', 'review_count', 'distance'
   

    response = requests.get(URL, headers=headers, params = params) # requests using the params_string

    data = response.json()

    return data

# %%
# before the looping, delete any existing csv file with the name like:
for POI_name, POI_ID in dict_POI_yelp.items():
    # delete the existing csv file
    # replace the space in the POI_name with '_', so the file name is valid
    # replace the ',_' in the POI_ID with '_', so the file name is valid
    d = data_path+'POI_yelp_'+POI_name.replace(' ', '_')+'_'+POI_ID.replace(', ', '_')+'.csv'
    # !rm $d

# call the function to get the POIs around each station, for each stations, for each POI category:
# Out:
# rm: ../data/POI_yelp_Restaurant_restaurants_All.csv: No such file or directory
# rm: ../data/POI_yelp_Bar_bars_All.csv: No such file or directory
# rm: ../data/POI_yelp_Park_parks_All.csv: No such file or directory
# rm: ../data/POI_yelp_Transport_Hub_transport_All.csv: No such file or directory
# rm: ../data/POI_yelp_Fuel_Station_servicestations_All.csv: No such file or directory
# rm: ../data/POI_yelp_EV_Charging_Station_evchargingstations_All.csv: No such file or directory
# rm: ../data/POI_yelp_Parking_parking_All.csv: No such file or directory

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
for POI_name, POI_ID in dict_POI_yelp.items():
    print('\033[93m' + '\n===============================' + '\033[0m')    
    print("name: ", POI_name, "id: ", POI_ID)
    
    # for each entry in DF_target_city_stations, find the POIs around it:
    df_yelp_POIs_around_stations = pd.DataFrame()

    for i in range(len(DF_target_city_stations)): # debug, only run for the first station # range(3) : # 

        print('\n===============================')       
        print('station: ', DF_target_city_stations['station_name'][i]) 
        print("name: ", POI_name, "id: ", POI_ID)# debug
        # try:
        result_yelp = get_venues_ll_category_yelp(DF_target_city_stations['latitude'][i], DF_target_city_stations['longitude'][i], POI_ID)

        df_yelp_normalize_1run_method = pd.json_normalize(result_yelp['businesses'], record_path=['categories'], meta=['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'rating', 'price', 'phone',
                                        'display_phone', 'distance'], record_prefix='categories_', errors='ignore') # 'transactions', column is not always returned and raising error, so ignore it.

        # add the station_ID to  df_yelp_normalize_1run_method, and fill it with the station ID from DF_target_city_stations['station_id'][i]
        df_yelp_normalize_1run_method['station_id'] = DF_target_city_stations['station_id'][i]

        # add a station_name collumn to  df_yelp_normalize_1run_method, and fill it with the station name from DF_target_city_stations['station_name'][i]
        df_yelp_normalize_1run_method['station_name'] = DF_target_city_stations['station_name'][i]
        
        # add a POI_ID collumn to  df_FS_normalize_1run_method, and fill it with the POI_ID from dict_POI_FS[POI_ID]
        df_yelp_normalize_1run_method['POI_category_ID'] = dict_POI_FS[POI_name]
        
        # add a POI_name collumn to  df_FS_normalize_1run_method, and fill it with the POI_name from dict_POI_FS[POI_ID]
        df_yelp_normalize_1run_method['POI_category_name'] = POI_name
        
        
        # concat the  df_yelp_normalize_1run_method to df_yelp_POIs_around_stations
        df_yelp_POIs_around_stations = pd.concat([df_yelp_POIs_around_stations, df_yelp_normalize_1run_method], axis=0)
        print(df_yelp_POIs_around_stations.shape)
            
        # except:
            # print('Error code: ', sys.exc_info()[0])

    
    try:
        df_yelp_POIs_around_stations = df_yelp_POIs_around_stations[['POI_category_name', 'POI_category_ID', 'station_id', 'station_name', 'id', 'alias', 'name',
                'image_url', 'is_closed', 'url', 'review_count', 'rating', 'price',
                'phone', 'display_phone', 'distance', 'categories_alias', 'categories_title']]
    except:
        print('Error code: ', sys.exc_info()[0])
    
    # rename columns: id -> POI_id, alias -> POI_alias, name -> POI_name
    df_yelp_POIs_around_stations = df_yelp_POIs_around_stations.rename(columns={'id': 'POI_id', 'alias': 'POI_alias', 'name': 'POI_name'})
    
    # save to a csv file corresponding to the POI category
    df_yelp_POIs_around_stations.to_csv(data_path+'POI_yelp_'+POI_name.replace(' ', '_')+'_'+POI_ID.replace(', ', '_').replace(' ', '_')+'.csv', index=False)



print('\nyelp loop Done!')
# Out:
# ===============================
# name:  Restaurant id:  restaurants, All
#
# ===============================
# station:  10th & Cambie
# name:  Restaurant id:  restaurants, All
# (93, 18)
#
# ===============================
# station:  Yaletown-Roundhouse Station
# name:  Restaurant id:  restaurants, All
# (193, 18)
#
# ===============================
# station:  Dunsmuir & Beatty
# name:  Restaurant id:  restaurants, All
# (280, 18)
#
# ===============================
# station:  12th & Yukon (City Hall)
# name:  Restaurant id:  restaurants, All
# (372, 18)
#
# ===============================
# station:  8th & Ash
# name:  Restaurant id:  restaurants, All
# (465, 18)
#
# ===============================
# station:  Spyglass & Seawall
# name:  Restaurant id:  restaurants, All
# (569, 18)
#
# ===============================
# station:  Stamps Landing
# name:  Restaurant id:  restaurants, All
# (668, 18)
#
# ===============================
# station:  Ontario & Seawall
# name:  Restaurant id:  restaurants, All
# (771, 18)
#
# ===============================
# station:  Canada Place
# name:  Restaurant id:  restaurants, All
# (864, 18)
#
# ===============================
# station:  Granville & Georgia
# name:  Restaurant id:  restaurants, All
# (957, 18)
#
# ===============================
# station:  Pender & Burrard
# name:  Restaurant id:  restaurants, All
# (1040, 18)
#
# ===============================
# station:  Marinaside & Davie
# name:  Restaurant id:  restaurants, All
# (1140, 18)
#
# ===============================
# station:  Robson & Hornby
# name:  Restaurant id:  restaurants, All
# (1231, 18)
#
# ===============================
# station:  Cordova & Granville
# name:  Restaurant id:  restaurants, All
# (1323, 18)
#
# ===============================
# station:  Hornby & Pender
# name:  Restaurant id:  restaurants, All
# (1416, 18)
#
# ===============================
# station:  Homer & Robson (Vancouver Public Library)
# name:  Restaurant id:  restaurants, All
# (1507, 18)
#
# ===============================
# station:  Beatty & Robson
# name:  Restaurant id:  restaurants, All
# (1610, 18)
#
# ===============================
# station:  Beatty & Nelson
# name:  Restaurant id:  restaurants, All
# (1710, 18)
#
# ===============================
# station:  Abbott & Cordova
# name:  Restaurant id:  restaurants, All
# (1809, 18)
#
# ===============================
# station:  Comox & Denman
# name:  Restaurant id:  restaurants, All
# (1903, 18)
#
# ===============================
# station:  Cordova & Bute
# name:  Restaurant id:  restaurants, All
# (1994, 18)
#
# ===============================
# station:  Hornby & Nelson
# name:  Restaurant id:  restaurants, All
# (2083, 18)
#
# ===============================
# station:  Helmcken & Burrard
# name:  Restaurant id:  restaurants, All
# (2185, 18)
#
# ===============================
# station:  Pacific & Richards
# name:  Restaurant id:  restaurants, All
# (2284, 18)
#
# ===============================
# station:  Chilco & Beach
# name:  Restaurant id:  restaurants, All
# (2379, 18)
#
# ===============================
# station:  Comox & Broughton
# name:  Restaurant id:  restaurants, All
# (2473, 18)
#
# ===============================
# station:  Bute & Comox
# name:  Restaurant id:  restaurants, All
# (2569, 18)
#
# ===============================
# station:  Cambie & Water
# name:  Restaurant id:  restaurants, All
# (2662, 18)
#
# ===============================
# station:  Keefer & Abbott
# name:  Restaurant id:  restaurants, All
# (2753, 18)
#
# ===============================
# station:  Expo & Carrall
# name:  Restaurant id:  restaurants, All
# (2837, 18)
#
# ===============================
# station:  Keefer & Columbia
# name:  Restaurant id:  restaurants, All
# (2929, 18)
#
# ===============================
# station:  Marinaside & Cooperage
# name:  Restaurant id:  restaurants, All
# (3035, 18)
#
# ===============================
# station:  Bidwell & Burnaby
# name:  Restaurant id:  restaurants, All
# (3130, 18)
#
# ===============================
# station:  Robson & Granville
# name:  Restaurant id:  restaurants, All
# (3217, 18)
#
# ===============================
# station:  Expo & Smithe
# name:  Restaurant id:  restaurants, All
# (3319, 18)
#
# ===============================
# station:  Cypress & Cornwall
# name:  Restaurant id:  restaurants, All
# (3414, 18)
#
# ===============================
# station:  Anderson & 2nd
# name:  Restaurant id:  restaurants, All
# (3512, 18)
#
# ===============================
# station:  7th & Granville
# name:  Restaurant id:  restaurants, All
# (3610, 18)
#
# ===============================
# station:  10th & Granville
# name:  Restaurant id:  restaurants, All
# (3710, 18)
#
# ===============================
# station:  14th & Granville
# name:  Restaurant id:  restaurants, All
# (3807, 18)
#
# ===============================
# station:  14th & Cambie
# name:  Restaurant id:  restaurants, All
# (3898, 18)
#
# ===============================
# station:  Ontario & 5th
# name:  Restaurant id:  restaurants, All
# (3997, 18)
#
# ===============================
# station:  10th & Main
# name:  Restaurant id:  restaurants, All
# (4095, 18)
#
# ===============================
# station:  Cypress & 4th
# name:  Restaurant id:  restaurants, All
# (4181, 18)
#
# ===============================
# station:  Vanier Park
# name:  Restaurant id:  restaurants, All
# (4287, 18)
#
# ===============================
# station:  Nelson & Mainland
# name:  Restaurant id:  restaurants, All
# (4386, 18)
#
# ===============================
# station:  Nelson & Richards
# name:  Restaurant id:  restaurants, All
# (4480, 18)
#
# ===============================
# station:  7th & Heather
# name:  Restaurant id:  restaurants, All
# (4574, 18)
#
# ===============================
# station:  Harwood & Bute
# name:  Restaurant id:  restaurants, All
# (4669, 18)
#
# ===============================
# station:  Chilco & Barclay
# name:  Restaurant id:  restaurants, All
# (4772, 18)
#
# ===============================
# station:  Chilco & Robson
# name:  Restaurant id:  restaurants, All
# (4877, 18)
#
# ===============================
# station:  Nicola & Robson
# name:  Restaurant id:  restaurants, All
# (4980, 18)
#
# ===============================
# station:  Carrall & Hastings
# name:  Restaurant id:  restaurants, All
# (5067, 18)
#
# ===============================
# station:  šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery
# name:  Restaurant id:  restaurants, All
# (5158, 18)
#
# ===============================
# station:  Stanley Park - Vancouver Aquarium
# name:  Restaurant id:  restaurants, All
# (5259, 18)
#
# ===============================
# station:  Stanley Park - Second Beach North
# name:  Restaurant id:  restaurants, All
# (5359, 18)
#
# ===============================
# station:  Stanley Park - Second Beach South
# name:  Restaurant id:  restaurants, All
# (5458, 18)
#
# ===============================
# station:  Stanley Park - Totem Poles
# name:  Restaurant id:  restaurants, All
# (5555, 18)
#
# ===============================
# station:  Heather & 14th
# name:  Restaurant id:  restaurants, All
# (5645, 18)
#
# ===============================
# station:  8th & Ontario
# name:  Restaurant id:  restaurants, All
# (5743, 18)
#
# ===============================
# station:  1st & Chestnut
# name:  Restaurant id:  restaurants, All
# (5835, 18)
#
# ===============================
# station:  7th & Arbutus
# name:  Restaurant id:  restaurants, All
# (5926, 18)
#
# ===============================
# station:  5th & Arbutus
# name:  Restaurant id:  restaurants, All
# (6015, 18)
#
# ===============================
# station:  10th & Oak
# name:  Restaurant id:  restaurants, All
# (6107, 18)
#
# ===============================
# station:  Arbutus & 16th
# name:  Restaurant id:  restaurants, All
# (6215, 18)
#
# ===============================
# station:  Cypress & 14th
# name:  Restaurant id:  restaurants, All
# (6316, 18)
#
# ===============================
# station:  Cypress & 16th
# name:  Restaurant id:  restaurants, All
# (6416, 18)
#
# ===============================
# station:  Georgia & Thurlow
# name:  Restaurant id:  restaurants, All
# (6518, 18)
#
# ===============================
# station:  Thurlow & Pendrell
# name:  Restaurant id:  restaurants, All
# (6610, 18)
#
# ===============================
# station:  Heather & 16th
# name:  Restaurant id:  restaurants, All
# (6699, 18)
#
# ===============================
# station:  14th & Ontario
# name:  Restaurant id:  restaurants, All
# (6790, 18)
#
# ===============================
# station:  14th & Main
# name:  Restaurant id:  restaurants, All
# (6884, 18)
#
# ===============================
# station:  David Lam Park - West
# name:  Restaurant id:  restaurants, All
# (6987, 18)
#
# ===============================
# station:  Beach & Seymour
# name:  Restaurant id:  restaurants, All
# (7085, 18)
#
# ===============================
# station:  Richards & Helmcken
# name:  Restaurant id:  restaurants, All
# (7185, 18)
#
# ===============================
# station:  Burrard & 4th
# name:  Restaurant id:  restaurants, All
# (7272, 18)
#
# ===============================
# station:  Burrard & 7th
# name:  Restaurant id:  restaurants, All
# (7363, 18)
#
# ===============================
# station:  South False Creek Seawall
# name:  Restaurant id:  restaurants, All
# (7458, 18)
#
# ===============================
# station:  Chestnut & McNicoll
# name:  Restaurant id:  restaurants, All
# (7560, 18)
#
# ===============================
# station:  Creekside Park North
# name:  Restaurant id:  restaurants, All
# (7651, 18)
#
# ===============================
# station:  Alexander & Main
# name:  Restaurant id:  restaurants, All
# (7736, 18)
#
# ===============================
# station:  Arbutus Greenway & 14th
# name:  Restaurant id:  restaurants, All
# (7840, 18)
#
# ===============================
# station:  Arbutus Greenway & Fir
# name:  Restaurant id:  restaurants, All
# (7937, 18)
#
# ===============================
# station:  Kitsilano Beach Park
# name:  Restaurant id:  restaurants, All
# (8034, 18)
#
# ===============================
# station:  Arbutus & McNicoll
# name:  Restaurant id:  restaurants, All
# (8129, 18)
#
# ===============================
# station:  Vine & 4th
# name:  Restaurant id:  restaurants, All
# (8223, 18)
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Restaurant id:  restaurants, All
# (8315, 18)
#
# ===============================
# station:  Alder & 11th
# name:  Restaurant id:  restaurants, All
# (8411, 18)
#
# ===============================
# station:  10th & Columbia
# name:  Restaurant id:  restaurants, All
# (8501, 18)
#
# ===============================
# station:  1st & Manitoba
# name:  Restaurant id:  restaurants, All
# (8604, 18)
#
# ===============================
# station:  10th & Ontario
# name:  Restaurant id:  restaurants, All
# (8704, 18)
#
# ===============================
# station:  Quebec & 1st
# name:  Restaurant id:  restaurants, All
# (8809, 18)
#
# ===============================
# station:  Columbia & 14th
# name:  Restaurant id:  restaurants, All
# (8905, 18)
#
# ===============================
# station:  Bute & Davie
# name:  Restaurant id:  restaurants, All
# (9001, 18)
#
# ===============================
# station:  7th & Laurel
# name:  Restaurant id:  restaurants, All
# (9093, 18)
#
# ===============================
# station:  7th &  Alder
# name:  Restaurant id:  restaurants, All
# (9193, 18)
#
# ===============================
# station:  Science World
# name:  Restaurant id:  restaurants, All
# (9295, 18)
#
# ===============================
# station:  1st & Scotia
# name:  Restaurant id:  restaurants, All
# (9405, 18)
#
# ===============================
# station:  Georgia & Main
# name:  Restaurant id:  restaurants, All
# (9498, 18)
#
# ===============================
# station:  Shaw Tower
# name:  Restaurant id:  restaurants, All
# (9584, 18)
#
# ===============================
# station:  Pine & 14th
# name:  Restaurant id:  restaurants, All
# (9678, 18)
#
# ===============================
# station:  York & Yew
# name:  Restaurant id:  restaurants, All
# (9772, 18)
#
# ===============================
# station:  Pine & 10th
# name:  Restaurant id:  restaurants, All
# (9870, 18)
#
# ===============================
# station:  8th & Scotia
# name:  Restaurant id:  restaurants, All
# (9968, 18)
#
# ===============================
# station:  Alberni & Jervis
# name:  Restaurant id:  restaurants, All
# (10071, 18)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Restaurant id:  restaurants, All
# (10171, 18)
#
# ===============================
# station:  14th & Alder
# name:  Restaurant id:  restaurants, All
# (10263, 18)
#
# ===============================
# station:  Pender & Gore
# name:  Restaurant id:  restaurants, All
# (10354, 18)
#
# ===============================
# station:  Carrall & Seawall
# name:  Restaurant id:  restaurants, All
# (10438, 18)
#
# ===============================
# station:  Glen & Union
# name:  Restaurant id:  restaurants, All
# (10532, 18)
#
# ===============================
# station:  Adanac & McLean
# name:  Restaurant id:  restaurants, All
# (10621, 18)
#
# ===============================
# station:  Commercial & Adanac
# name:  Restaurant id:  restaurants, All
# (10713, 18)
#
# ===============================
# station:  Pender & Commercial
# name:  Restaurant id:  restaurants, All
# (10803, 18)
#
# ===============================
# station:  Keefer & Princess
# name:  Restaurant id:  restaurants, All
# (10896, 18)
#
# ===============================
# station:  Alexander & Railway
# name:  Restaurant id:  restaurants, All
# (10990, 18)
#
# ===============================
# station:  Napier & Commercial
# name:  Restaurant id:  restaurants, All
# (11082, 18)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Restaurant id:  restaurants, All
# (11171, 18)
#
# ===============================
# station:  Thornton & National
# name:  Restaurant id:  restaurants, All
# (11275, 18)
#
# ===============================
# station:  Keith & 6th
# name:  Restaurant id:  restaurants, All
# (11370, 18)
#
# ===============================
# station:  Glen & 6th
# name:  Restaurant id:  restaurants, All
# (11466, 18)
#
# ===============================
# station:  Grant & Commercial
# name:  Restaurant id:  restaurants, All
# (11562, 18)
#
# ===============================
# station:  2nd & Commercial
# name:  Restaurant id:  restaurants, All
# (11659, 18)
#
# ===============================
# station:  4th & Commercial
# name:  Restaurant id:  restaurants, All
# (11755, 18)
#
# ===============================
# station:  8th & Commercial
# name:  Restaurant id:  restaurants, All
# (11850, 18)
#
# ===============================
# station:  10th & Commercial
# name:  Restaurant id:  restaurants, All
# (11945, 18)
#
# ===============================
# station:  Woodland & 10th
# name:  Restaurant id:  restaurants, All
# (12038, 18)
#
# ===============================
# station:  Glen & Broadway
# name:  Restaurant id:  restaurants, All
# (12127, 18)
#
# ===============================
# station:  St George & Broadway
# name:  Restaurant id:  restaurants, All
# (12223, 18)
#
# ===============================
# station:  7th & Woodland
# name:  Restaurant id:  restaurants, All
# (12317, 18)
#
# ===============================
# station:  Woodland & 4th
# name:  Restaurant id:  restaurants, All
# (12410, 18)
#
# ===============================
# station:  Woodland & Graveley
# name:  Restaurant id:  restaurants, All
# (12508, 18)
#
# ===============================
# station:  Charles & Woodland
# name:  Restaurant id:  restaurants, All
# (12603, 18)
#
# ===============================
# station:  18th & Main
# name:  Restaurant id:  restaurants, All
# (12698, 18)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Restaurant id:  restaurants, All
# (12787, 18)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Restaurant id:  restaurants, All
# (12881, 18)
#
# ===============================
# station:  13th & St George
# name:  Restaurant id:  restaurants, All
# (12968, 18)
#
# ===============================
# station:  10th & Fraser
# name:  Restaurant id:  restaurants, All
# (13060, 18)
#
# ===============================
# station:  8th & Fraser
# name:  Restaurant id:  restaurants, All
# (13154, 18)
#
# ===============================
# station:  St Catherines & 10th
# name:  Restaurant id:  restaurants, All
# (13244, 18)
#
# ===============================
# station:  St Catherines & 7th
# name:  Restaurant id:  restaurants, All
# (13338, 18)
#
# ===============================
# station:  Pender & Victoria
# name:  Restaurant id:  restaurants, All
# (13434, 18)
#
# ===============================
# station:  Victoria & 4th
# name:  Restaurant id:  restaurants, All
# (13530, 18)
#
# ===============================
# station:  Victoria & 10th
# name:  Restaurant id:  restaurants, All
# (13628, 18)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Restaurant id:  restaurants, All
# (13715, 18)
#
# ===============================
# station:  Triumph & Victoria
# name:  Restaurant id:  restaurants, All
# (13812, 18)
#
# ===============================
# station:  Windsor & 14th
# name:  Restaurant id:  restaurants, All
# (13897, 18)
#
# ===============================
# station:  14th & Fraser
# name:  Restaurant id:  restaurants, All
# (13986, 18)
#
# ===============================
# station:  15th & Knight
# name:  Restaurant id:  restaurants, All
# (14081, 18)
#
# ===============================
# station:  Commercial & Pandora
# name:  Restaurant id:  restaurants, All
# (14174, 18)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Restaurant id:  restaurants, All
# (14276, 18)
#
# ===============================
# station:  6th & Prince Edward
# name:  Restaurant id:  restaurants, All
# (14377, 18)
#
# ===============================
# station:  6th & Carolina
# name:  Restaurant id:  restaurants, All
# (14480, 18)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Restaurant id:  restaurants, All
# (14483, 18)
#
# ===============================
# station:  Union & Dunlevy
# name:  Restaurant id:  restaurants, All
# (14579, 18)
#
# ===============================
# station:  Keefer & Hawks
# name:  Restaurant id:  restaurants, All
# (14674, 18)
#
# ===============================
# station:  Hawks & Union
# name:  Restaurant id:  restaurants, All
# (14776, 18)
#
# ===============================
# station:  Charles & Commercial
# name:  Restaurant id:  restaurants, All
# (14873, 18)
#
# ===============================
# station:  10th & Kingsway
# name:  Restaurant id:  restaurants, All
# (14971, 18)
#
# ===============================
# station:  Beach & Hornby
# name:  Restaurant id:  restaurants, All
# (15071, 18)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Restaurant id:  restaurants, All
# (15160, 18)
#
# ===============================
# station:  Bute & Barclay
# name:  Restaurant id:  restaurants, All
# (15265, 18)
#
# ===============================
# station:  8th & Yukon
# name:  Restaurant id:  restaurants, All
# (15360, 18)
#
# ===============================
# station:  Princess & Union
# name:  Restaurant id:  restaurants, All
# (15456, 18)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Restaurant id:  restaurants, All
# (15552, 18)
#
# ===============================
# station:  5th & Main
# name:  Restaurant id:  restaurants, All
# (15649, 18)
#
# ===============================
# station:  3rd & Quebec
# name:  Restaurant id:  restaurants, All
# (15748, 18)
#
# ===============================
# station:  Richards & Cordova
# name:  Restaurant id:  restaurants, All
# (15845, 18)
#
# ===============================
# station:  Richards & Robson
# name:  Restaurant id:  restaurants, All
# (15936, 18)
#
# ===============================
# station:  Olympic Village Station
# name:  Restaurant id:  restaurants, All
# (16032, 18)
#
# ===============================
# station:  Campbell & Hastings
# name:  Restaurant id:  restaurants, All
# (16126, 18)
#
# ===============================
# station:  Cardero & Davie
# name:  Restaurant id:  restaurants, All
# (16220, 18)
#
# ===============================
# station:  Aquatic Centre
# name:  Restaurant id:  restaurants, All
# (16313, 18)
#
# ===============================
# station:  Beach & Broughton
# name:  Restaurant id:  restaurants, All
# (16409, 18)
#
# ===============================
# station:  Beach & Cardero
# name:  Restaurant id:  restaurants, All
# (16505, 18)
#
# ===============================
# station:  Georgia & Homer
# name:  Restaurant id:  restaurants, All
# (16599, 18)
#
# ===============================
# station:  Columbia & 5th
# name:  Restaurant id:  restaurants, All
# (16693, 18)
#
# ===============================
# station:  Haro & Denman
# name:  Restaurant id:  restaurants, All
# (16799, 18)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Restaurant id:  restaurants, All
# (16801, 18)
#
# ===============================
# station:  Arbutus & 10th
# name:  Restaurant id:  restaurants, All
# (16895, 18)
#
# ===============================
# station:  Ontario & 16th
# name:  Restaurant id:  restaurants, All
# (16991, 18)
#
# ===============================
# station:  Richards & Davie
# name:  Restaurant id:  restaurants, All
# (17086, 18)
#
# ===============================
# station:  8th & Prince Edward
# name:  Restaurant id:  restaurants, All
# (17186, 18)
#
# ===============================
# station:  Jervis & Robson
# name:  Restaurant id:  restaurants, All
# (17289, 18)
#
# ===============================
# station:  Smithe & Burrard
# name:  Restaurant id:  restaurants, All
# (17390, 18)
#
# ===============================
# station:  Broughton & Davie
# name:  Restaurant id:  restaurants, All
# (17488, 18)
#
# ===============================
# station:  Cypress & 10th
# name:  Restaurant id:  restaurants, All
# (17588, 18)
#
# ===============================
# station:  Granville Island
# name:  Restaurant id:  restaurants, All
# (17685, 18)
#
# ===============================
# station:  McLean & Pender
# name:  Restaurant id:  restaurants, All
# (17776, 18)
#
# ===============================
# station:  Richards & Smithe
# name:  Restaurant id:  restaurants, All
# (17865, 18)
#
# ===============================
# station:  Bute & Robson
# name:  Restaurant id:  restaurants, All
# (17967, 18)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Restaurant id:  restaurants, All
# (18061, 18)
#
# ===============================
# station:  Alma & Point Grey
# name:  Restaurant id:  restaurants, All
# (18170, 18)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Restaurant id:  restaurants, All
# (18277, 18)
#
# ===============================
# station:  Hastings & Broughton
# name:  Restaurant id:  restaurants, All
# (18377, 18)
#
# ===============================
# station:  Yew & Broadway
# name:  Restaurant id:  restaurants, All
# (18474, 18)
#
# ===============================
# station:  8th & Macdonald
# name:  Restaurant id:  restaurants, All
# (18575, 18)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Restaurant id:  restaurants, All
# (18683, 18)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Restaurant id:  restaurants, All
# (18791, 18)
#
# ===============================
# station:  Grandview & Commercial
# name:  Restaurant id:  restaurants, All
# (18885, 18)
#
# ===============================
# station:  14th & Oak
# name:  Restaurant id:  restaurants, All
# (18976, 18)
#
# ===============================
# station:  Wallace & 4th
# name:  Restaurant id:  restaurants, All
# (19063, 18)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Restaurant id:  restaurants, All
# (19159, 18)
#
# ===============================
# station:  Balaclava & 6th
# name:  Restaurant id:  restaurants, All
# (19265, 18)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Restaurant id:  restaurants, All
# (19366, 18)
#
# ===============================
# station:  Dunbar & 6th
# name:  Restaurant id:  restaurants, All
# (19474, 18)
#
# ===============================
# station:  18th & Cambie
# name:  Restaurant id:  restaurants, All
# (19565, 18)
#
# ===============================
# station:  Blenheim & 4th
# name:  Restaurant id:  restaurants, All
# (19672, 18)
#
# ===============================
# station:  18th & Heather
# name:  Restaurant id:  restaurants, All
# (19760, 18)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Restaurant id:  restaurants, All
# (19859, 18)
#
# ===============================
# station:  20th & Main
# name:  Restaurant id:  restaurants, All
# (19959, 18)
#
# ===============================
# station:  Station & Terminal
# name:  Restaurant id:  restaurants, All
# (20068, 18)
#
# ===============================
# station:  Jericho Beach
# name:  Restaurant id:  restaurants, All
# (20155, 18)
#
# ===============================
# station:  Burrard & Drake
# name:  Restaurant id:  restaurants, All
# (20255, 18)
#
# ===============================
# station:  Columbia & 1st
# name:  Restaurant id:  restaurants, All
# (20356, 18)
#
# ===============================
# station:  Davie & Beach
# name:  Restaurant id:  restaurants, All
# (20451, 18)
#
# ===============================
# station:  Morton & Denman
# name:  Restaurant id:  restaurants, All
# (20545, 18)
#
# ===============================
# station:  13th & Cambie
# name:  Restaurant id:  restaurants, All
# (20639, 18)
#
# ===============================
# station:  Nelson & Denman
# name:  Restaurant id:  restaurants, All
# (20734, 18)
#
# ===============================
# station:  Melville & Bute
# name:  Restaurant id:  restaurants, All
# (20824, 18)
#
# ===============================
# station:  Seymour & Cordova
# name:  Restaurant id:  restaurants, All
# (20916, 18)
#
# ===============================
# station:  Arbutus & Nanton
# name:  Restaurant id:  restaurants, All
# (20919, 18)
#
# ===============================
# station:  Yukon & 6th
# name:  Restaurant id:  restaurants, All
# (21013, 18)
#
# ===============================
# station:  11th & Kingsway
# name:  Restaurant id:  restaurants, All
# (21111, 18)
#
# ===============================
# station:  Wylie & 2nd
# name:  Restaurant id:  restaurants, All
# (21201, 18)
#
# ===============================
# station:  29th & Cambie
# name:  Restaurant id:  restaurants, All
# (21247, 18)
#
# ===============================
# station:  Rolston & Granville
# name:  Restaurant id:  restaurants, All
# (21338, 18)
#
# ===============================
# station:  East Blvd & 37th
# name:  Restaurant id:  restaurants, All
# (21433, 18)
#
# ===============================
# station:  28th & Willow
# name:  Restaurant id:  restaurants, All
# (21488, 18)
#
# ===============================
# station:  Ontario & 23rd
# name:  Restaurant id:  restaurants, All
# (21594, 18)
#
# ===============================
# station:  30th & Ontario
# name:  Restaurant id:  restaurants, All
# (21703, 18)
#
# ===============================
# station:  Franklin & Nanaimo
# name:  Restaurant id:  restaurants, All
# (21800, 18)
#
# ===============================
# station:  Lakewood & Triumph
# name:  Restaurant id:  restaurants, All
# (21901, 18)
#
# ===============================
# station:  Wall & Eton
# name:  Restaurant id:  restaurants, All
# (22002, 18)
#
# ===============================
# station:  Lakewood & Oxford
# name:  Restaurant id:  restaurants, All
# (22103, 18)
#
# ===============================
# station:  22nd & Cambie
# name:  Restaurant id:  restaurants, All
# (22199, 18)
#
# ===============================
# station:  King Edward & Cambie
# name:  Restaurant id:  restaurants, All
# (22290, 18)
#
# ===============================
# station:  Heather & 29th
# name:  Restaurant id:  restaurants, All
# (22342, 18)
#
# ===============================
# station:  Cardero & Robson
# name:  Restaurant id:  restaurants, All
# (22440, 18)
#
# ===============================
# station:  Commercial & 20th
# name:  Restaurant id:  restaurants, All
# (22526, 18)
#
# ===============================
# station:  Hornby & Drake
# name:  Restaurant id:  restaurants, All
# (22625, 18)
#
# ===============================
# station:  Burrard & 14th
# name:  Restaurant id:  restaurants, All
# (22723, 18)
#
# ===============================
# name:  Bar id:  bars, All
#
# ===============================
# station:  10th & Cambie
# name:  Bar id:  bars, All
# (57, 18)
#
# ===============================
# station:  Yaletown-Roundhouse Station
# name:  Bar id:  bars, All
# (172, 18)
#
# ===============================
# station:  Dunsmuir & Beatty
# name:  Bar id:  bars, All
# (294, 18)
#
# ===============================
# station:  12th & Yukon (City Hall)
# name:  Bar id:  bars, All
# (355, 18)
#
# ===============================
# station:  8th & Ash
# name:  Bar id:  bars, All
# (380, 18)
#
# ===============================
# station:  Spyglass & Seawall
# name:  Bar id:  bars, All
# (496, 18)
#
# ===============================
# station:  Stamps Landing
# name:  Bar id:  bars, All
# (601, 18)
#
# ===============================
# station:  Ontario & Seawall
# name:  Bar id:  bars, All
# (710, 18)
#
# ===============================
# station:  Canada Place
# name:  Bar id:  bars, All
# (823, 18)
#
# ===============================
# station:  Granville & Georgia
# name:  Bar id:  bars, All
# (939, 18)
#
# ===============================
# station:  Pender & Burrard
# name:  Bar id:  bars, All
# (1053, 18)
#
# ===============================
# station:  Marinaside & Davie
# name:  Bar id:  bars, All
# (1169, 18)
#
# ===============================
# station:  Robson & Hornby
# name:  Bar id:  bars, All
# (1287, 18)
#
# ===============================
# station:  Cordova & Granville
# name:  Bar id:  bars, All
# (1402, 18)
#
# ===============================
# station:  Hornby & Pender
# name:  Bar id:  bars, All
# (1518, 18)
#
# ===============================
# station:  Homer & Robson (Vancouver Public Library)
# name:  Bar id:  bars, All
# (1641, 18)
#
# ===============================
# station:  Beatty & Robson
# name:  Bar id:  bars, All
# (1763, 18)
#
# ===============================
# station:  Beatty & Nelson
# name:  Bar id:  bars, All
# (1883, 18)
#
# ===============================
# station:  Abbott & Cordova
# name:  Bar id:  bars, All
# (1995, 18)
#
# ===============================
# station:  Comox & Denman
# name:  Bar id:  bars, All
# (2069, 18)
#
# ===============================
# station:  Cordova & Bute
# name:  Bar id:  bars, All
# (2179, 18)
#
# ===============================
# station:  Hornby & Nelson
# name:  Bar id:  bars, All
# (2290, 18)
#
# ===============================
# station:  Helmcken & Burrard
# name:  Bar id:  bars, All
# (2402, 18)
#
# ===============================
# station:  Pacific & Richards
# name:  Bar id:  bars, All
# (2518, 18)
#
# ===============================
# station:  Chilco & Beach
# name:  Bar id:  bars, All
# (2562, 18)
#
# ===============================
# station:  Comox & Broughton
# name:  Bar id:  bars, All
# (2675, 18)
#
# ===============================
# station:  Bute & Comox
# name:  Bar id:  bars, All
# (2784, 18)
#
# ===============================
# station:  Cambie & Water
# name:  Bar id:  bars, All
# (2896, 18)
#
# ===============================
# station:  Keefer & Abbott
# name:  Bar id:  bars, All
# (3011, 18)
#
# ===============================
# station:  Expo & Carrall
# name:  Bar id:  bars, All
# (3116, 18)
#
# ===============================
# station:  Keefer & Columbia
# name:  Bar id:  bars, All
# (3218, 18)
#
# ===============================
# station:  Marinaside & Cooperage
# name:  Bar id:  bars, All
# (3335, 18)
#
# ===============================
# station:  Bidwell & Burnaby
# name:  Bar id:  bars, All
# (3401, 18)
#
# ===============================
# station:  Robson & Granville
# name:  Bar id:  bars, All
# (3518, 18)
#
# ===============================
# station:  Expo & Smithe
# name:  Bar id:  bars, All
# (3639, 18)
#
# ===============================
# station:  Cypress & Cornwall
# name:  Bar id:  bars, All
# (3692, 18)
#
# ===============================
# station:  Anderson & 2nd
# name:  Bar id:  bars, All
# (3769, 18)
#
# ===============================
# station:  7th & Granville
# name:  Bar id:  bars, All
# (3818, 18)
#
# ===============================
# station:  10th & Granville
# name:  Bar id:  bars, All
# (3856, 18)
#
# ===============================
# station:  14th & Granville
# name:  Bar id:  bars, All
# (3879, 18)
#
# ===============================
# station:  14th & Cambie
# name:  Bar id:  bars, All
# (3904, 18)
#
# ===============================
# station:  Ontario & 5th
# name:  Bar id:  bars, All
# (3976, 18)
#
# ===============================
# station:  10th & Main
# name:  Bar id:  bars, All
# (4042, 18)
#
# ===============================
# station:  Cypress & 4th
# name:  Bar id:  bars, All
# (4103, 18)
#
# ===============================
# station:  Vanier Park
# name:  Bar id:  bars, All
# (4167, 18)
#
# ===============================
# station:  Nelson & Mainland
# name:  Bar id:  bars, All
# (4283, 18)
#
# ===============================
# station:  Nelson & Richards
# name:  Bar id:  bars, All
# (4398, 18)
#
# ===============================
# station:  7th & Heather
# name:  Bar id:  bars, All
# (4424, 18)
#
# ===============================
# station:  Harwood & Bute
# name:  Bar id:  bars, All
# (4536, 18)
#
# ===============================
# station:  Chilco & Barclay
# name:  Bar id:  bars, All
# (4588, 18)
#
# ===============================
# station:  Chilco & Robson
# name:  Bar id:  bars, All
# (4646, 18)
#
# ===============================
# station:  Nicola & Robson
# name:  Bar id:  bars, All
# (4755, 18)
#
# ===============================
# station:  Carrall & Hastings
# name:  Bar id:  bars, All
# (4860, 18)
#
# ===============================
# station:  šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery
# name:  Bar id:  bars, All
# (4978, 18)
#
# ===============================
# station:  Stanley Park - Vancouver Aquarium
# name:  Bar id:  bars, All
# (4997, 18)
#
# ===============================
# station:  Stanley Park - Second Beach North
# name:  Bar id:  bars, All
# (5023, 18)
#
# ===============================
# station:  Stanley Park - Second Beach South
# name:  Bar id:  bars, All
# (5049, 18)
#
# ===============================
# station:  Stanley Park - Totem Poles
# name:  Bar id:  bars, All
# (5065, 18)
#
# ===============================
# station:  Heather & 14th
# name:  Bar id:  bars, All
# (5079, 18)
#
# ===============================
# station:  8th & Ontario
# name:  Bar id:  bars, All
# (5151, 18)
#
# ===============================
# station:  1st & Chestnut
# name:  Bar id:  bars, All
# (5212, 18)
#
# ===============================
# station:  7th & Arbutus
# name:  Bar id:  bars, All
# (5266, 18)
#
# ===============================
# station:  5th & Arbutus
# name:  Bar id:  bars, All
# (5316, 18)
#
# ===============================
# station:  10th & Oak
# name:  Bar id:  bars, All
# (5349, 18)
#
# ===============================
# station:  Arbutus & 16th
# name:  Bar id:  bars, All
# (5373, 18)
#
# ===============================
# station:  Cypress & 14th
# name:  Bar id:  bars, All
# (5402, 18)
#
# ===============================
# station:  Cypress & 16th
# name:  Bar id:  bars, All
# (5426, 18)
#
# ===============================
# station:  Georgia & Thurlow
# name:  Bar id:  bars, All
# (5535, 18)
#
# ===============================
# station:  Thurlow & Pendrell
# name:  Bar id:  bars, All
# (5646, 18)
#
# ===============================
# station:  Heather & 16th
# name:  Bar id:  bars, All
# (5660, 18)
#
# ===============================
# station:  14th & Ontario
# name:  Bar id:  bars, All
# (5731, 18)
#
# ===============================
# station:  14th & Main
# name:  Bar id:  bars, All
# (5796, 18)
#
# ===============================
# station:  David Lam Park - West
# name:  Bar id:  bars, All
# (5910, 18)
#
# ===============================
# station:  Beach & Seymour
# name:  Bar id:  bars, All
# (6023, 18)
#
# ===============================
# station:  Richards & Helmcken
# name:  Bar id:  bars, All
# (6137, 18)
#
# ===============================
# station:  Burrard & 4th
# name:  Bar id:  bars, All
# (6203, 18)
#
# ===============================
# station:  Burrard & 7th
# name:  Bar id:  bars, All
# (6265, 18)
#
# ===============================
# station:  South False Creek Seawall
# name:  Bar id:  bars, All
# (6359, 18)
#
# ===============================
# station:  Chestnut & McNicoll
# name:  Bar id:  bars, All
# (6410, 18)
#
# ===============================
# station:  Creekside Park North
# name:  Bar id:  bars, All
# (6515, 18)
#
# ===============================
# station:  Alexander & Main
# name:  Bar id:  bars, All
# (6618, 18)
#
# ===============================
# station:  Arbutus Greenway & 14th
# name:  Bar id:  bars, All
# (6648, 18)
#
# ===============================
# station:  Arbutus Greenway & Fir
# name:  Bar id:  bars, All
# (6701, 18)
#
# ===============================
# station:  Kitsilano Beach Park
# name:  Bar id:  bars, All
# (6731, 18)
#
# ===============================
# station:  Arbutus & McNicoll
# name:  Bar id:  bars, All
# (6757, 18)
#
# ===============================
# station:  Vine & 4th
# name:  Bar id:  bars, All
# (6797, 18)
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Bar id:  bars, All
# (6886, 18)
#
# ===============================
# station:  Alder & 11th
# name:  Bar id:  bars, All
# (6915, 18)
#
# ===============================
# station:  10th & Columbia
# name:  Bar id:  bars, All
# (6984, 18)
#
# ===============================
# station:  1st & Manitoba
# name:  Bar id:  bars, All
# (7093, 18)
#
# ===============================
# station:  10th & Ontario
# name:  Bar id:  bars, All
# (7160, 18)
#
# ===============================
# station:  Quebec & 1st
# name:  Bar id:  bars, All
# (7254, 18)
#
# ===============================
# station:  Columbia & 14th
# name:  Bar id:  bars, All
# (7322, 18)
#
# ===============================
# station:  Bute & Davie
# name:  Bar id:  bars, All
# (7435, 18)
#
# ===============================
# station:  7th & Laurel
# name:  Bar id:  bars, All
# (7463, 18)
#
# ===============================
# station:  7th &  Alder
# name:  Bar id:  bars, All
# (7503, 18)
#
# ===============================
# station:  Science World
# name:  Bar id:  bars, All
# (7610, 18)
#
# ===============================
# station:  1st & Scotia
# name:  Bar id:  bars, All
# (7674, 18)
#
# ===============================
# station:  Georgia & Main
# name:  Bar id:  bars, All
# (7775, 18)
#
# ===============================
# station:  Shaw Tower
# name:  Bar id:  bars, All
# (7885, 18)
#
# ===============================
# station:  Pine & 14th
# name:  Bar id:  bars, All
# (7914, 18)
#
# ===============================
# station:  York & Yew
# name:  Bar id:  bars, All
# (7954, 18)
#
# ===============================
# station:  Pine & 10th
# name:  Bar id:  bars, All
# (8005, 18)
#
# ===============================
# station:  8th & Scotia
# name:  Bar id:  bars, All
# (8068, 18)
#
# ===============================
# station:  Alberni & Jervis
# name:  Bar id:  bars, All
# (8180, 18)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Bar id:  bars, All
# (8207, 18)
#
# ===============================
# station:  14th & Alder
# name:  Bar id:  bars, All
# (8225, 18)
#
# ===============================
# station:  Pender & Gore
# name:  Bar id:  bars, All
# (8326, 18)
#
# ===============================
# station:  Carrall & Seawall
# name:  Bar id:  bars, All
# (8433, 18)
#
# ===============================
# station:  Glen & Union
# name:  Bar id:  bars, All
# (8472, 18)
#
# ===============================
# station:  Adanac & McLean
# name:  Bar id:  bars, All
# (8511, 18)
#
# ===============================
# station:  Commercial & Adanac
# name:  Bar id:  bars, All
# (8556, 18)
#
# ===============================
# station:  Pender & Commercial
# name:  Bar id:  bars, All
# (8586, 18)
#
# ===============================
# station:  Keefer & Princess
# name:  Bar id:  bars, All
# (8649, 18)
#
# ===============================
# station:  Alexander & Railway
# name:  Bar id:  bars, All
# (8710, 18)
#
# ===============================
# station:  Napier & Commercial
# name:  Bar id:  bars, All
# (8749, 18)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Bar id:  bars, All
# (8788, 18)
#
# ===============================
# station:  Thornton & National
# name:  Bar id:  bars, All
# (8862, 18)
#
# ===============================
# station:  Keith & 6th
# name:  Bar id:  bars, All
# (8895, 18)
#
# ===============================
# station:  Glen & 6th
# name:  Bar id:  bars, All
# (8928, 18)
#
# ===============================
# station:  Grant & Commercial
# name:  Bar id:  bars, All
# (8963, 18)
#
# ===============================
# station:  2nd & Commercial
# name:  Bar id:  bars, All
# (8998, 18)
#
# ===============================
# station:  4th & Commercial
# name:  Bar id:  bars, All
# (9033, 18)
#
# ===============================
# station:  8th & Commercial
# name:  Bar id:  bars, All
# (9060, 18)
#
# ===============================
# station:  10th & Commercial
# name:  Bar id:  bars, All
# (9076, 18)
#
# ===============================
# station:  Woodland & 10th
# name:  Bar id:  bars, All
# (9087, 18)
#
# ===============================
# station:  Glen & Broadway
# name:  Bar id:  bars, All
# (9113, 18)
#
# ===============================
# station:  St George & Broadway
# name:  Bar id:  bars, All
# (9173, 18)
#
# ===============================
# station:  7th & Woodland
# name:  Bar id:  bars, All
# (9202, 18)
#
# ===============================
# station:  Woodland & 4th
# name:  Bar id:  bars, All
# (9237, 18)
#
# ===============================
# station:  Woodland & Graveley
# name:  Bar id:  bars, All
# (9272, 18)
#
# ===============================
# station:  Charles & Woodland
# name:  Bar id:  bars, All
# (9308, 18)
#
# ===============================
# station:  18th & Main
# name:  Bar id:  bars, All
# (9367, 18)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Bar id:  bars, All
# (9421, 18)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Bar id:  bars, All
# (9483, 18)
#
# ===============================
# station:  13th & St George
# name:  Bar id:  bars, All
# (9542, 18)
#
# ===============================
# station:  10th & Fraser
# name:  Bar id:  bars, All
# (9594, 18)
#
# ===============================
# station:  8th & Fraser
# name:  Bar id:  bars, All
# (9642, 18)
#
# ===============================
# station:  St Catherines & 10th
# name:  Bar id:  bars, All
# (9658, 18)
#
# ===============================
# station:  St Catherines & 7th
# name:  Bar id:  bars, All
# (9673, 18)
#
# ===============================
# station:  Pender & Victoria
# name:  Bar id:  bars, All
# (9706, 18)
#
# ===============================
# station:  Victoria & 4th
# name:  Bar id:  bars, All
# (9741, 18)
#
# ===============================
# station:  Victoria & 10th
# name:  Bar id:  bars, All
# (9752, 18)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Bar id:  bars, All
# (9755, 18)
#
# ===============================
# station:  Triumph & Victoria
# name:  Bar id:  bars, All
# (9775, 18)
#
# ===============================
# station:  Windsor & 14th
# name:  Bar id:  bars, All
# (9787, 18)
#
# ===============================
# station:  14th & Fraser
# name:  Bar id:  bars, All
# (9840, 18)
#
# ===============================
# station:  15th & Knight
# name:  Bar id:  bars, All
# (9843, 18)
#
# ===============================
# station:  Commercial & Pandora
# name:  Bar id:  bars, All
# (9860, 18)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Bar id:  bars, All
# (9914, 18)
#
# ===============================
# station:  6th & Prince Edward
# name:  Bar id:  bars, All
# (9975, 18)
#
# ===============================
# station:  6th & Carolina
# name:  Bar id:  bars, All
# (10027, 18)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Bar id:  bars, All
# (10027, 18)
#
# ===============================
# station:  Union & Dunlevy
# name:  Bar id:  bars, All
# (10127, 18)
#
# ===============================
# station:  Keefer & Hawks
# name:  Bar id:  bars, All
# (10168, 18)
#
# ===============================
# station:  Hawks & Union
# name:  Bar id:  bars, All
# (10213, 18)
#
# ===============================
# station:  Charles & Commercial
# name:  Bar id:  bars, All
# (10254, 18)
#
# ===============================
# station:  10th & Kingsway
# name:  Bar id:  bars, All
# (10314, 18)
#
# ===============================
# station:  Beach & Hornby
# name:  Bar id:  bars, All
# (10427, 18)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Bar id:  bars, All
# (10538, 18)
#
# ===============================
# station:  Bute & Barclay
# name:  Bar id:  bars, All
# (10640, 18)
#
# ===============================
# station:  8th & Yukon
# name:  Bar id:  bars, All
# (10704, 18)
#
# ===============================
# station:  Princess & Union
# name:  Bar id:  bars, All
# (10773, 18)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Bar id:  bars, All
# (10901, 18)
#
# ===============================
# station:  5th & Main
# name:  Bar id:  bars, All
# (10968, 18)
#
# ===============================
# station:  3rd & Quebec
# name:  Bar id:  bars, All
# (11038, 18)
#
# ===============================
# station:  Richards & Cordova
# name:  Bar id:  bars, All
# (11156, 18)
#
# ===============================
# station:  Richards & Robson
# name:  Bar id:  bars, All
# (11277, 18)
#
# ===============================
# station:  Olympic Village Station
# name:  Bar id:  bars, All
# (11328, 18)
#
# ===============================
# station:  Campbell & Hastings
# name:  Bar id:  bars, All
# (11351, 18)
#
# ===============================
# station:  Cardero & Davie
# name:  Bar id:  bars, All
# (11452, 18)
#
# ===============================
# station:  Aquatic Centre
# name:  Bar id:  bars, All
# (11570, 18)
#
# ===============================
# station:  Beach & Broughton
# name:  Bar id:  bars, All
# (11671, 18)
#
# ===============================
# station:  Beach & Cardero
# name:  Bar id:  bars, All
# (11739, 18)
#
# ===============================
# station:  Georgia & Homer
# name:  Bar id:  bars, All
# (11863, 18)
#
# ===============================
# station:  Columbia & 5th
# name:  Bar id:  bars, All
# (11956, 18)
#
# ===============================
# station:  Haro & Denman
# name:  Bar id:  bars, All
# (12043, 18)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Bar id:  bars, All
# (12043, 18)
#
# ===============================
# station:  Arbutus & 10th
# name:  Bar id:  bars, All
# (12088, 18)
#
# ===============================
# station:  Ontario & 16th
# name:  Bar id:  bars, All
# (12152, 18)
#
# ===============================
# station:  Richards & Davie
# name:  Bar id:  bars, All
# (12266, 18)
#
# ===============================
# station:  8th & Prince Edward
# name:  Bar id:  bars, All
# (12329, 18)
#
# ===============================
# station:  Jervis & Robson
# name:  Bar id:  bars, All
# (12439, 18)
#
# ===============================
# station:  Smithe & Burrard
# name:  Bar id:  bars, All
# (12552, 18)
#
# ===============================
# station:  Broughton & Davie
# name:  Bar id:  bars, All
# (12670, 18)
#
# ===============================
# station:  Cypress & 10th
# name:  Bar id:  bars, All
# (12721, 18)
#
# ===============================
# station:  Granville Island
# name:  Bar id:  bars, All
# (12833, 18)
#
# ===============================
# station:  McLean & Pender
# name:  Bar id:  bars, All
# (12858, 18)
#
# ===============================
# station:  Richards & Smithe
# name:  Bar id:  bars, All
# (12979, 18)
#
# ===============================
# station:  Bute & Robson
# name:  Bar id:  bars, All
# (13084, 18)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Bar id:  bars, All
# (13114, 18)
#
# ===============================
# station:  Alma & Point Grey
# name:  Bar id:  bars, All
# (13131, 18)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Bar id:  bars, All
# (13158, 18)
#
# ===============================
# station:  Hastings & Broughton
# name:  Bar id:  bars, All
# (13270, 18)
#
# ===============================
# station:  Yew & Broadway
# name:  Bar id:  bars, All
# (13301, 18)
#
# ===============================
# station:  8th & Macdonald
# name:  Bar id:  bars, All
# (13331, 18)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Bar id:  bars, All
# (13358, 18)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Bar id:  bars, All
# (13378, 18)
#
# ===============================
# station:  Grandview & Commercial
# name:  Bar id:  bars, All
# (13407, 18)
#
# ===============================
# station:  14th & Oak
# name:  Bar id:  bars, All
# (13434, 18)
#
# ===============================
# station:  Wallace & 4th
# name:  Bar id:  bars, All
# (13448, 18)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Bar id:  bars, All
# (13485, 18)
#
# ===============================
# station:  Balaclava & 6th
# name:  Bar id:  bars, All
# (13512, 18)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Bar id:  bars, All
# (13542, 18)
#
# ===============================
# station:  Dunbar & 6th
# name:  Bar id:  bars, All
# (13562, 18)
#
# ===============================
# station:  18th & Cambie
# name:  Bar id:  bars, All
# (13592, 18)
#
# ===============================
# station:  Blenheim & 4th
# name:  Bar id:  bars, All
# (13619, 18)
#
# ===============================
# station:  18th & Heather
# name:  Bar id:  bars, All
# (13633, 18)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Bar id:  bars, All
# (13655, 18)
#
# ===============================
# station:  20th & Main
# name:  Bar id:  bars, All
# (13707, 18)
#
# ===============================
# station:  Station & Terminal
# name:  Bar id:  bars, All
# (13779, 18)
#
# ===============================
# station:  Jericho Beach
# name:  Bar id:  bars, All
# (13792, 18)
#
# ===============================
# station:  Burrard & Drake
# name:  Bar id:  bars, All
# (13905, 18)
#
# ===============================
# ...
#
# ===============================
# station:  Alexander & Dunlevy
# name:  Parking id:  parking, All
# (596, 18)
#
# ===============================
# station:  Alder & 11th
# name:  Parking id:  parking, All
# (598, 18)
#
# ===============================
# station:  10th & Columbia
# name:  Parking id:  parking, All
# (600, 18)
#
# ===============================
# station:  1st & Manitoba
# name:  Parking id:  parking, All
# (603, 18)
#
# ===============================
# station:  10th & Ontario
# name:  Parking id:  parking, All
# (604, 18)
#
# ===============================
# station:  Quebec & 1st
# name:  Parking id:  parking, All
# (607, 18)
#
# ===============================
# station:  Columbia & 14th
# name:  Parking id:  parking, All
# (609, 18)
#
# ===============================
# station:  Bute & Davie
# name:  Parking id:  parking, All
# (615, 18)
#
# ===============================
# station:  7th & Laurel
# name:  Parking id:  parking, All
# (617, 18)
#
# ===============================
# station:  7th &  Alder
# name:  Parking id:  parking, All
# (619, 18)
#
# ===============================
# station:  Science World
# name:  Parking id:  parking, All
# (626, 18)
#
# ===============================
# station:  1st & Scotia
# name:  Parking id:  parking, All
# (627, 18)
#
# ===============================
# station:  Georgia & Main
# name:  Parking id:  parking, All
# (639, 18)
#
# ===============================
# station:  Shaw Tower
# name:  Parking id:  parking, All
# (658, 18)
#
# ===============================
# station:  Pine & 14th
# name:  Parking id:  parking, All
# (659, 18)
#
# ===============================
# station:  York & Yew
# name:  Parking id:  parking, All
# (659, 18)
#
# ===============================
# station:  Pine & 10th
# name:  Parking id:  parking, All
# (660, 18)
#
# ===============================
# station:  8th & Scotia
# name:  Parking id:  parking, All
# (661, 18)
#
# ===============================
# station:  Alberni & Jervis
# name:  Parking id:  parking, All
# (673, 18)
#
# ===============================
# station:  Stanley Park - Information Booth
# name:  Parking id:  parking, All
# (674, 18)
#
# ===============================
# station:  14th & Alder
# name:  Parking id:  parking, All
# (676, 18)
#
# ===============================
# station:  Pender & Gore
# name:  Parking id:  parking, All
# (680, 18)
#
# ===============================
# station:  Carrall & Seawall
# name:  Parking id:  parking, All
# (693, 18)
#
# ===============================
# station:  Glen & Union
# name:  Parking id:  parking, All
# (693, 18)
#
# ===============================
# station:  Adanac & McLean
# name:  Parking id:  parking, All
# (693, 18)
#
# ===============================
# station:  Commercial & Adanac
# name:  Parking id:  parking, All
# (693, 18)
#
# ===============================
# station:  Pender & Commercial
# name:  Parking id:  parking, All
# (693, 18)
#
# ===============================
# station:  Keefer & Princess
# name:  Parking id:  parking, All
# (696, 18)
#
# ===============================
# station:  Alexander & Railway
# name:  Parking id:  parking, All
# (699, 18)
#
# ===============================
# station:  Napier & Commercial
# name:  Parking id:  parking, All
# (699, 18)
#
# ===============================
# station:  Britannia Parking Lot
# name:  Parking id:  parking, All
# (699, 18)
#
# ===============================
# station:  Thornton & National
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Keith & 6th
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Glen & 6th
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Grant & Commercial
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  2nd & Commercial
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  4th & Commercial
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  8th & Commercial
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  10th & Commercial
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Woodland & 10th
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Glen & Broadway
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  St George & Broadway
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  7th & Woodland
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Woodland & 4th
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Woodland & Graveley
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  Charles & Woodland
# name:  Parking id:  parking, All
# (702, 18)
#
# ===============================
# station:  18th & Main
# name:  Parking id:  parking, All
# (703, 18)
#
# ===============================
# station:  Prince Edward & 16th
# name:  Parking id:  parking, All
# (704, 18)
#
# ===============================
# station:  Prince Edward & 14th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  13th & St George
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  10th & Fraser
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  8th & Fraser
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  St Catherines & 10th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  St Catherines & 7th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Pender & Victoria
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Victoria & 4th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Victoria & 10th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  15th & Victoria (Trout Lake)
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Triumph & Victoria
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Windsor & 14th
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  14th & Fraser
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  15th & Knight
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Commercial & Pandora
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  Carolina & Great Northern Way
# name:  Parking id:  parking, All
# (705, 18)
#
# ===============================
# station:  6th & Prince Edward
# name:  Parking id:  parking, All
# (706, 18)
#
# ===============================
# station:  6th & Carolina
# name:  Parking id:  parking, All
# (706, 18)
#
# ===============================
# station:  Stanley Park - Third Beach Parking Lot
# name:  Parking id:  parking, All
# (706, 18)
#
# ===============================
# station:  Union & Dunlevy
# name:  Parking id:  parking, All
# (710, 18)
#
# ===============================
# station:  Keefer & Hawks
# name:  Parking id:  parking, All
# (711, 18)
#
# ===============================
# station:  Hawks & Union
# name:  Parking id:  parking, All
# (712, 18)
#
# ===============================
# station:  Charles & Commercial
# name:  Parking id:  parking, All
# (712, 18)
#
# ===============================
# station:  10th & Kingsway
# name:  Parking id:  parking, All
# (713, 18)
#
# ===============================
# station:  Beach & Hornby
# name:  Parking id:  parking, All
# (715, 18)
#
# ===============================
# station:  Burrard Station (Melville & Dunsmuir)
# name:  Parking id:  parking, All
# (735, 18)
#
# ===============================
# station:  Bute & Barclay
# name:  Parking id:  parking, All
# (746, 18)
#
# ===============================
# station:  8th & Yukon
# name:  Parking id:  parking, All
# (748, 18)
#
# ===============================
# station:  Princess & Union
# name:  Parking id:  parking, All
# (751, 18)
#
# ===============================
# station:  Dunsmuir & Richards
# name:  Parking id:  parking, All
# (771, 18)
#
# ===============================
# station:  5th & Main
# name:  Parking id:  parking, All
# (772, 18)
#
# ===============================
# station:  3rd & Quebec
# name:  Parking id:  parking, All
# (773, 18)
#
# ===============================
# station:  Richards & Cordova
# name:  Parking id:  parking, All
# (794, 18)
#
# ===============================
# station:  Richards & Robson
# name:  Parking id:  parking, All
# (814, 18)
#
# ===============================
# station:  Olympic Village Station
# name:  Parking id:  parking, All
# (816, 18)
#
# ===============================
# station:  Campbell & Hastings
# name:  Parking id:  parking, All
# (817, 18)
#
# ===============================
# station:  Cardero & Davie
# name:  Parking id:  parking, All
# (820, 18)
#
# ===============================
# station:  Aquatic Centre
# name:  Parking id:  parking, All
# (821, 18)
#
# ===============================
# station:  Beach & Broughton
# name:  Parking id:  parking, All
# (824, 18)
#
# ===============================
# station:  Beach & Cardero
# name:  Parking id:  parking, All
# (826, 18)
#
# ===============================
# station:  Georgia & Homer
# name:  Parking id:  parking, All
# (847, 18)
#
# ===============================
# station:  Columbia & 5th
# name:  Parking id:  parking, All
# (849, 18)
#
# ===============================
# station:  Haro & Denman
# name:  Parking id:  parking, All
# (851, 18)
#
# ===============================
# station:  Stanley Park - Prospect Point
# name:  Parking id:  parking, All
# (851, 18)
#
# ===============================
# station:  Arbutus & 10th
# name:  Parking id:  parking, All
# (851, 18)
#
# ===============================
# station:  Ontario & 16th
# name:  Parking id:  parking, All
# (852, 18)
#
# ===============================
# station:  Richards & Davie
# name:  Parking id:  parking, All
# (862, 18)
#
# ===============================
# station:  8th & Prince Edward
# name:  Parking id:  parking, All
# (863, 18)
#
# ===============================
# station:  Jervis & Robson
# name:  Parking id:  parking, All
# (874, 18)
#
# ===============================
# station:  Smithe & Burrard
# name:  Parking id:  parking, All
# (894, 18)
#
# ===============================
# station:  Broughton & Davie
# name:  Parking id:  parking, All
# (897, 18)
#
# ===============================
# station:  Cypress & 10th
# name:  Parking id:  parking, All
# (898, 18)
#
# ===============================
# station:  Granville Island
# name:  Parking id:  parking, All
# (901, 18)
#
# ===============================
# station:  McLean & Pender
# name:  Parking id:  parking, All
# (901, 18)
#
# ===============================
# station:  Richards & Smithe
# name:  Parking id:  parking, All
# (921, 18)
#
# ===============================
# station:  Bute & Robson
# name:  Parking id:  parking, All
# (933, 18)
#
# ===============================
# station:  Trafalgar & Cornwall
# name:  Parking id:  parking, All
# (933, 18)
#
# ===============================
# station:  Alma & Point Grey
# name:  Parking id:  parking, All
# (933, 18)
#
# ===============================
# station:  Point Grey & Blenheim
# name:  Parking id:  parking, All
# (933, 18)
#
# ===============================
# station:  Hastings & Broughton
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  Yew & Broadway
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  8th & Macdonald
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  Balaclava & Broadway
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  Dunbar & Broadway
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  Grandview & Commercial
# name:  Parking id:  parking, All
# (943, 18)
#
# ===============================
# station:  14th & Oak
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  Wallace & 4th
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  Balsam & Cornwall
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  Balaclava & 6th
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  Trafalgar & Broadway
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  Dunbar & 6th
# name:  Parking id:  parking, All
# (945, 18)
#
# ===============================
# station:  18th & Cambie
# name:  Parking id:  parking, All
# (947, 18)
#
# ===============================
# station:  Blenheim & 4th
# name:  Parking id:  parking, All
# (947, 18)
#
# ===============================
# station:  18th & Heather
# name:  Parking id:  parking, All
# (949, 18)
#
# ===============================
# station:  Point Grey & Bayswater
# name:  Parking id:  parking, All
# (949, 18)
#
# ===============================
# station:  20th & Main
# name:  Parking id:  parking, All
# (949, 18)
#
# ===============================
# station:  Station & Terminal
# name:  Parking id:  parking, All
# (951, 18)
#
# ===============================
# station:  Jericho Beach
# name:  Parking id:  parking, All
# (951, 18)
#
# ===============================
# station:  Burrard & Drake
# name:  Parking id:  parking, All
# (956, 18)
#
# ===============================
# station:  Columbia & 1st
# name:  Parking id:  parking, All
# (958, 18)
#
# ===============================
# station:  Davie & Beach
# name:  Parking id:  parking, All
# (960, 18)
#
# ===============================
# station:  Morton & Denman
# name:  Parking id:  parking, All
# (961, 18)
#
# ===============================
# station:  13th & Cambie
# name:  Parking id:  parking, All
# (963, 18)
#
# ===============================
# station:  Nelson & Denman
# name:  Parking id:  parking, All
# (965, 18)
#
# ===============================
# station:  Melville & Bute
# name:  Parking id:  parking, All
# (985, 18)
#
# ===============================
# station:  Seymour & Cordova
# name:  Parking id:  parking, All
# (1005, 18)
#
# ===============================
# station:  Arbutus & Nanton
# name:  Parking id:  parking, All
# (1005, 18)
#
# ===============================
# station:  Yukon & 6th
# name:  Parking id:  parking, All
# (1007, 18)
#
# ===============================
# station:  11th & Kingsway
# name:  Parking id:  parking, All
# (1008, 18)
#
# ===============================
# station:  Wylie & 2nd
# name:  Parking id:  parking, All
# (1010, 18)
#
# ===============================
# station:  29th & Cambie
# name:  Parking id:  parking, All
# (1010, 18)
#
# ===============================
# station:  Rolston & Granville
# name:  Parking id:  parking, All
# (1012, 18)
#
# ===============================
# station:  East Blvd & 37th
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  28th & Willow
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Ontario & 23rd
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  30th & Ontario
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Franklin & Nanaimo
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Lakewood & Triumph
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Wall & Eton
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Lakewood & Oxford
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  22nd & Cambie
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  King Edward & Cambie
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Heather & 29th
# name:  Parking id:  parking, All
# (1013, 18)
#
# ===============================
# station:  Cardero & Robson
# name:  Parking id:  parking, All
# (1017, 18)
#
# ===============================
# station:  Commercial & 20th
# name:  Parking id:  parking, All
# (1017, 18)
#
# ===============================
# station:  Hornby & Drake
# name:  Parking id:  parking, All
# (1022, 18)
#
# ===============================
# station:  Burrard & 14th
# name:  Parking id:  parking, All
# (1023, 18)
#
# yelp loop Done!

# %%
# read back the data and check the shape:

# Find all the names under the data_path and like 'POI_yelp_*.csv'
file_name_list_yelp = !ls $data_path | grep 'POI_yelp_.*.csv'
file_name_list_yelp

# create a list of dataframes, named as POI_yelp_* and read the corresponding csv files
for file in file_name_list_yelp:
    shape_of_it = None
    # print the file path and name
    print(file[:-4]) # .replace(' ', '_')[:-4])
    # create a dataframe named as file.replace(' ', '_')
    # read the csv file with the file name, withou the '.csv' surfix
    try:
        exec(file[:-4] + ' = pd.read_csv(data_path+file)')
        # check the shape of the dataframe, save to a variable named as shape_of_it
        exec('shape_of_it = '+file[:-4]+'.shape')
        print('shape_of_it: ', shape_of_it)    
        # if shape_of_it is NoneType, then print the error message
        if shape_of_it[0] == 0:
            print('\033[1;31m' + file[:-4] + ' is Empty!' + '\033[0m')
    except:
        print('Error code: ', sys.exc_info()[0])
        print('\033[1;31m' + file[:-4] + ' is Empty!' + '\033[0m')
# Out:
# ['POI_yelp_Bar_bars_All.csv',
#  'POI_yelp_EV_Charging_Station_evchargingstations_All.csv',
#  'POI_yelp_Fuel_Station_servicestations_All.csv',
#  'POI_yelp_Park_parks_All.csv',
#  'POI_yelp_Parking_parking_All.csv',
#  'POI_yelp_Restaurant_restaurants_All.csv',
#  'POI_yelp_Transport_Hub_transport_All.csv']
# POI_yelp_Bar_bars_All
# shape_of_it:  (15243, 18)
# POI_yelp_EV_Charging_Station_evchargingstations_All
# shape_of_it:  (99, 18)
# POI_yelp_Fuel_Station_servicestations_All
# shape_of_it:  (904, 18)
# POI_yelp_Park_parks_All
# shape_of_it:  (2902, 18)
# POI_yelp_Parking_parking_All
# shape_of_it:  (1023, 18)
# POI_yelp_Restaurant_restaurants_All
# shape_of_it:  (22723, 18)
# POI_yelp_Transport_Hub_transport_All
# shape_of_it:  (5120, 18)

# %%
# compare the shape of those dataframs by the variable names: _yelp, _FS_ generate a dataframe to store the shape of each dataframe

# extract the string between the 2nd '_' and the 3rd '_' from the keys of dict_POI_yelp, into a list keep the order
table_columns = [file_name_list_FS[i].split('_')[2] for i in range(len(file_name_list_FS))]

# table value to eval the shape of the dataframe with the name in the list: file_name_list_FS
table_value_FS = [eval(file_name_list_FS[i][:-4] + '.shape') for i in range(len(file_name_list_FS))]

table_value_yelp = [eval(file_name_list_yelp[i][:-4] + '.shape') for i in range(len(file_name_list_yelp))]

# create a dataframe using: table_columns as columns; table_value_FS and table_value_yelp as values
# table_columns 's 1st row the table_value_FS, 2nd row the table_value_yelp

table_compare = pd.DataFrame([table_value_FS, table_value_yelp],columns=table_columns, index=['FS', 'yelp'])

# add one column 'Total' to: sum the first elements of each tuple as the first elements of the result tuple, and average of the second element of each tuple as the second element of the result tuple
table_compare['Total'] = table_compare.apply(lambda x: (sum([x[i][0] for i in range(len(x))]), round(sum([x[i][1] for i in range(len(x))])/len(x))), axis=1)

# in a new table called table_compare_readable, compare the two values in the two rows in each column, if the first element of tuptle is larger,write a string "win" in the cell, else write a string "lose" in the cell
# table_compare_readable = table_compare.copy()
table_compare_readable = table_compare.copy()
for i in range(len(table_compare.columns)):
    if table_compare.iloc[0,i][0] > table_compare.iloc[1,i][0]:
        table_compare_readable.iloc[0,i] = 'win'
        table_compare_readable.iloc[1,i] = 'lose'
    else:
        table_compare_readable.iloc[0,i] = 'lose'
        table_compare_readable.iloc[1,i] = 'win'

# count the win or lose each row get, and add a new column 'Total' to the table_compare_readable
table_compare_readable['Total WinLose'] = table_compare_readable.apply(lambda x: (sum([x[i] == 'win' for i in range(len(x))]), sum([x[i] == 'lose' for i in range(len(x))])), axis=1)

table_compare_readable
# Out:
#               Bar         EV       Fuel        Park     Parking   Restaurant  \
# FS    (14053, 13)  (156, 13)  (824, 13)  (3739, 13)  (2650, 13)  (21012, 13)
# yelp  (15243, 18)   (99, 18)  (904, 18)  (2902, 18)  (1023, 18)  (22723, 18)
#
#        Transport
# FS    (4996, 13)
# yelp  (5120, 18)
#               Bar         EV       Fuel        Park     Parking   Restaurant  \
# FS    (14053, 13)  (156, 13)  (824, 13)  (3739, 13)  (2650, 13)  (21012, 13)
# yelp  (15243, 18)   (99, 18)  (904, 18)  (2902, 18)  (1023, 18)  (22723, 18)
#
#        Transport        Total
# FS    (4996, 13)  (47430, 13)
# yelp  (5120, 18)  (48014, 18)
#        Bar    EV  Fuel  Park Parking Restaurant Transport Total Total WinLose
# FS    lose   win  lose   win     win       lose      lose  lose        (3, 5)
# yelp   win  lose   win  lose    lose        win       win   win        (5, 3)

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# * By similar query parameters, we can see that the yelp data has 18 columns, while the FS data has 13 columns. It means yelp return more data columns than FS, for example, the yelp data has the column 'review_count' and 'rating'.
#
# * By comparing the number of returns in each category and subtotal, we can get the win/lose summary for the two sites. Yelp wins in 4 categories and the subtotal, while FS wins in 3 categories and loses the subtotal.
#
# * Therefore, we can conclude that the yelp data is more comprehensive than the FS data.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
# There are too many 5 star rating restaurants, so the review_count is needed to be considered.
# sort the review and POI_yelp_Restaurant_restaurants_All, by rating, review_count. list the three columns: POI_name, rating, review_count
# due to the duplicated categories, subset it by the columns: 'POI_name', 'rating', 'review_count'. Then drop the duplicated rows. inplace = False
POI_yelp_Restaurant_restaurants_All[['POI_name', 'rating', 'review_count']].drop_duplicates().sort_values(by=['rating', 'review_count'], ascending=False).head(10)
# Out:
#                       POI_name  rating  review_count
# 2251                Manoush'eh     5.0           224
# 3176          Incognito Coffee     5.0           146
# 15002            Number e food     5.0           135
# 1537              Smithe Salad     5.0            62
# 3600   Mazahr Lebanese Kitchen     5.0            38
# 10470    The Garden Strathcona     5.0            36
# 10505            Caffe La Tana     5.0            30
# 1891          Arike Restaurant     5.0            25
# 750      Blaze Gourmet Burgers     5.0            19
# 4933     Good Dogs Plant Foods     5.0            19
